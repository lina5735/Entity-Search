# %% [markdown]
# !python -m spacy download en_core_web_md

# %%
import spacy
import os
import pandas as pd
import calendar

# %%
# 加载语言模型
nlp = spacy.load("en_core_web_md")

# 文件夹路径
folder_path = "/Users/irisgong/Desktop/ISE540 Text Analytics/project/data/label/label_story"

retrieved_documents = {}


for filename in os.listdir(folder_path):
    if filename.endswith(".story"):
        file_path = os.path.join(folder_path, filename)

        # 读取文件内容
        with open(file_path, "r", encoding="utf-8") as file:
            document = file.read()
            
            people = set()
            organizations = set()
            locations = set()
            dates = set()
            doc = nlp(document)
            
            for ent in doc.ents:
                if ent.label_ == "PERSON":
                    people.add(ent.text)
                elif ent.label_ == "ORG":
                    organizations.add(ent.text)
                elif ent.label_ == "LOC":
                    locations.add(ent.text)
                elif ent.label_ == "GPE":
                    locations.add(ent.text)
                elif ent.label_ == "DATE":
                    dates.add(ent.text)
            
            # 创建当前文件的字典项
            result = {
                'People': people,
                'Organizations': organizations,
                'Locations': locations,
                'Dates': dates
            }
            
            # 将当前文件的结果存储到总的字典中
            retrieved_documents[filename] = result
            
            
retrieved_documents = dict(sorted(retrieved_documents.items(), key=lambda item: item[0]))


# 要删除的日期标签
unwanted_dates = {"Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday",}

for filename, result in retrieved_documents.items():
    result['Dates'] -= unwanted_dates
    

# 要删除的词组
unwanted_phrases = {"year", "month", "week", "day", "old", "annual", "season", "daily", "decade", "decades", "this", "next", "last", "more"}

for filename, result in retrieved_documents.items():
    result['Dates'] = {date for date in result['Dates'] if not any(word in date.lower() for word in unwanted_phrases)}
    
    
# 删除只含有一个月份单词的日期标签
months_to_remove = [month.lower() for month in calendar.month_name[1:]]

for filename, result in retrieved_documents.items():
    result['Dates'] = {date for date in result['Dates'] if not (date.lower() in months_to_remove and len(date.split()) == 1)}

# %%
# Ground truth

excel_path = "/Users/irisgong/Desktop/ISE540 Text Analytics/project/data/label/label.xlsx"
df = pd.read_excel(excel_path)

ground_truth = {}

for index, row in df.iterrows():

    file_id = row['id']
    
    # 如果逗号后没有空格，则加上空格
    people_raw = str(row['person']) if pd.notna(row['person']) else ""
    people_raw = ', '.join([p.strip() for p in people_raw.split(',')])
    people = set([p.strip() for p in people_raw.split(', ') if p.strip()])
    
    organizations_raw = str(row['organization']) if pd.notna(row['organization']) else ""
    organizations_raw = ', '.join([o.strip() for o in organizations_raw.split(',')])
    organizations = set([o.strip() for o in organizations_raw.split(', ') if o.strip()])
    
    locations_raw = str(row['location']) if pd.notna(row['location']) else ""
    locations_raw = ', '.join([l.strip() for l in locations_raw.split(',')])
    locations = set([l.strip() for l in locations_raw.split(', ') if l.strip()])

    dates_raw = str(row['date']) if pd.notna(row['date']) else ""
    dates_raw = ', '.join([d.strip() for d in dates_raw.split(',')])
    dates = set([d.strip() for d in dates_raw.split(', ') if d.strip()])


    result_1 = {
        'People': people,
        'Organizations': organizations,
        'Locations': locations,
        'Dates': dates
    }

    ground_truth[file_id] = result_1


ground_truth = dict(sorted(ground_truth.items()))


# 要删除的日期标签
unwanted_dates = {"Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday",}

for filename, result in ground_truth.items():
    result['Dates'] -= unwanted_dates
    

# 要删除的词组
unwanted_phrases = {"year", "month", "week", "day", "old", "annual", "season", "daily", "decade", "decades", "this", "next", "last", "more"}

for filename, result in ground_truth.items():
    result['Dates'] = {date for date in result['Dates'] if not any(word in date.lower() for word in unwanted_phrases)}
    
    
# 删除只含有一个月份单词的日期标签
months_to_remove = [month.lower() for month in calendar.month_name[1:]]

for filename, result in ground_truth.items():
    result['Dates'] = {date for date in result['Dates'] if not (date.lower() in months_to_remove and len(date.split()) == 1)}

# %%
retrieved_documents
# Out:
# {'0000800d9058217f6509d7e63ad475e2de0da611.story': {'People': {'Charlie Pugsley',
#    'Evelyn Raywood',
#    'Jake',
#    'Jean Booth',
#    'Kim Taylor',
#    'Laura Baty',
#    'Philip\n Le Shirley',
#    'Richard Spillett',
#    'Taylor',
#    'Yasin\n Patel',
#    'Yasin Patel'},
#   'Organizations': {'Ford',
#    'Prestige Vaping',
#    'the Royal Society for the Prevention of Accidents',
#    'the Wythenshawe Hospital'},
#   'Locations': {'Chesterfield',
#    'Derbyshire',
#    'East London',
#    'Fire\n ',
#    'Leicester',
#    'London',
#    'Manchester',
#    'North Yorkshire',
#    'Richmond'},
#   'Dates': {'11', '18', '26', '54'}},
#  '0001d4ce3598e37f20a47fe609736f72e5d73467.story': {'People': {'Cameron Atfield',
#    'Charles\n Vacca',
#    'Charles \nVaca',
#    'Charles Vacca',
#    'Jim McCabe',
#    'Liz\n Matthews',
#    'McCabe\n ',
#    'Mike Murphy',
#    'Nikki Bateman',
#    'Sam\n Scarmardo',
#    'Sam Scarmardo',
#    'Scarmardo',
#    'Vaca',
#    'Vacca'},
#   'Organizations': {'Army',
#    'Burgers',
#    'Burgers Adventure',
#    'ESPN',
#    'MSNBC',
#    'McCabe',
#    'NBC News\n ',
#    'Social\n ',
#    'UZI',
#    'Vacca',
#    'the Las Vegas Review Journal'},
#   'Locations': {'Arizona',
#    'Clark County',
#    'Lake Havasu City',
#    'Las Vegas',
#    'Mohave County',
#    'Nevada',
#    'New Jersey',
#    'Seattle',
#    'White Hills'},
#   'Dates': {'39'}},
#  '0002067d13d3ca304e0bc98d04dde85d4091c55e.story': {'People': {'Bert',
#    'Butterfield',
#    'Joe',
#    'Joe Smales',
#    'Maxwell',
#    'Niall Pawson',
#    'Paul Maxwell',
#    'Smales'},
#   'Organizations': {'Daily Mail',
#    'Greater Manchester Police',
#    'Leeds Crown Court',
#    'Maxwell',
#    'Tameside'},
#   'Locations': {'Rochdale',
#    'Wakefield',
#    'West Yorks',
#    'West Yorkshire',
#    'Â£7,000'},
#   'Dates': {'1996', '1998', '2011', '49', 'February 2014', 'June 1996'}},
#  '000219931d2c3aae55dc2acdc5f690d0c112ab17.story': {'People': {'Crown',
#    'Fraser Wylie',
#    'Gledhill',
#    'Jack Roland Crown',
#    'Judith Paynes',
#    'Mark Hopkins',
#    'Mrs Crown',
#    'Muddy',
#    'Nat Carey',
#    'Nat Cary',
#    'Simon Gledhill',
#    'Una Crown',
#    'William Morris'},
#   'Organizations': {'Coroner', 'Home Office', 'Una Crown'},
#   'Locations': {'Bedfordshire',
#    'Cambridgeshire',
#    'Hertfordshire',
#    'Huntingdon',
#    'Wisbech'},
#   'Dates': {'86', 'January 13 2013', 'January 13, 2013', 'June 2013'}},
#  '00022dbfa44ccdb94c1dc06938047e258076cf75.story': {'People': {'Chris Brooke',
#    'David Gordon',
#    'Paul',
#    'Paul Smith',
#    "Paul Smith's",
#    'Richard Woolfall',
#    'Smith'},
#   'Organizations': {'Army', 'Hull Crown Court', 'IRA', 'Smith', 'Taliban'},
#   'Locations': {'Afghanistan',
#    'East Hull',
#    'East Yorkshire',
#    'Hull',
#    'Northern Ireland'},
#   'Dates': {'3 September 2012'}},
#  '0002b1d590aa4d2f6f000a03947317b6dc4e5c18.story': {'People': {'Alexander Litvinenko',
#    'Anatoli',
#    'Andrei Lugovoy',
#    'Ben Emmerson QC',
#    'Davies',
#    'Dmitry Kovturn',
#    'Hugh Davies',
#    'Kovtun',
#    'Litvinenko',
#    'Marina Litvinenko',
#    'Mark Duell',
#    'Robert',
#    'Robert Owen',
#    'Ryan Kisiel',
#    'Vladimir Putin'},
#   'Organizations': {'Coroner',
#    'High Court',
#    'KGB',
#    'MI5',
#    'MI6',
#    'Scotland Yard',
#    'The Daily Mail',
#    'The Metropolitan Police Service',
#    'the Crown \nProsecution Service',
#    'the Millennium \nHotel'},
#   'Locations': {'Britain', 'London', 'Marina', 'Moscow', 'Russia', 'UK'},
#   'Dates': {'20 September 2012', '2006', '43', 'November 1, 2006'}},
#  '0002b6c22d2efa3af4971f9d515178bb89e31934.story': {'People': {'Gary Kelly',
#    'Gary KellyGreater',
#    'Maden',
#    'Marcel Maden',
#    "Marcel Maden's",
#    'Mark Duell'},
#   'Organizations': {'Facebook',
#    'Greater Manchester \nPolice',
#    'Manchester Crown Court',
#    'Salford house',
#    'Smith & Wesson',
#    'iPhone'},
#   'Locations': {'DC', 'Greater Manchester', 'Salford'},
#   'Dates': {'14 March 2013', '19'}},
#  '0002c17436637c4fe1837c935c04de47adb18e9a.story': {'People': {'Blaga Stancheva',
#    'Burkhart',
#    'Burkharts',
#    'Carney',
#    'Cooley',
#    'Dorothee',
#    'Dorothee Burkhart',
#    'Edward Nordskog',
#    'Gunther Meilinger',
#    'Harry',
#    'Harry Burkhart',
#    'Nordskog',
#    'Sean Carney',
#    'Stancheva',
#    'Steve Cooley',
#    'U.S. Marshals',
#    'Upinder Kalra'},
#   'Organizations': {"Burkhart's", 'CNN'},
#   'Locations': {'British Columbia',
#    'California',
#    'Canada',
#    'Frankfurt',
#    'Germany',
#    'Hollywood',
#    'Los Angeles',
#    'Los Angeles County',
#    'Los Angeles District',
#    'Los Angeles Superior Court',
#    'Neukirchen',
#    'Sherman Oaks',
#    'Stancheva',
#    'Vancouver',
#    'West Hollywood',
#    'the United States'},
#   'Dates': {'2004',
#    '2010',
#    'January 24',
#    'September, 2011',
#    'between 2000 and 2006',
#    'early March of 2010'}},
#  '00030c0cba08a5b361fd3ecb4dbf232da8269c55.story': {'People': {'Barbara Roberts',
#    'Brad',
#    'Graham Smith',
#    'Mrs Roberts',
#    "Ms Roberts'",
#    'Roger',
#    'Roger\n\n'},
#   'Organizations': {'Owner', 'Withington Hedgehog Hospital Trust'},
#   'Locations': {'Basil', 'Charlotte', 'Manchester', 'Willow'},
#   'Dates': {'2001', '2025', '23 June 2012', '60'}},
#  '0003ad6ef0c37534f80b55b4235108024b407f0b.story': {'People': {'Ari Abdallah Morales',
#    'Cody Ray Smith',
#    'Jose Carlos Montano',
#    'Manuel Ortega',
#    'Marcelles James Peter',
#    'Mark Gagan',
#    'Morales',
#    'Peter',
#    'Salvador Rodriguez',
#    'Smith'},
#   'Organizations': {'CNN', 'the Richmond High School'},
#   'Locations': {'California', 'Montano', 'Richmond', 'San Pablo'},
#   'Dates': {'18', '19', '21'}},
#  '00050e5dbf398963ad40cb6ff81c918c932cc809.story': {'People': {'Edd',
#    'Edd Filiti',
#    'Jennifer Flavin',
#    'Mark Berry',
#    'Mike Larkin',
#    'RadarOnline',
#    'Rambo',
#    'Sage',
#    'Sasha',
#    'Sasha Czack',
#    'Sly',
#    'Stallone',
#    'Sylvester',
#    "Sylvester Stallone's",
#    'Toni Ann'},
#   'Organizations': {'Facebook',
#    'LAPD',
#    'RadarOnline',
#    "Sage Stallone's",
#    "Sage's",
#    'Stallone',
#    'the New York Post'},
#   'Locations': {'Hollywood',
#    'Hollywood Hills',
#    'Los Angeles Police \nDepartment'},
#   'Dates': {'16 July 2012',
#    '17 July 2012',
#    '1985',
#    '1990',
#    '1996',
#    '1997',
#    'July 6'}},
#  '000513feba4745611532547b50df128c5ea564e4.story': {'People': {'Alderman Antonio',
#    'Antonio French',
#    "Antonio French's",
#    'Darren Wilson',
#    "Darren Wilson's",
#    'Darren Wilson\xa0\n\n\xa0\n\n',
#    'Jay Nixon',
#    'Michael Brown',
#    'Nixon',
#    'Thomas Jackson',
#    'Wilson'},
#   'Organizations': {'ABC',
#    'ABC News',
#    'Ferguson',
#    'National Guard',
#    'The National Guard',
#    'the National Guard'},
#   'Locations': {'Ferguson', 'Missouri', 'St Louis', 'West Florissant'},
#   'Dates': set()},
#  '0005c9808410ba585973fdf2eaa0d1bb9070546e.story': {'People': {'Beccy',
#    'Beccy Rochow',
#    'Beccy Ruchow',
#    'Bird',
#    'Byron Bay',
#    'Greg Bird',
#    "Greg Bird's"},
#   'Organizations': {'Bird',
#    'Four Nations',
#    'Gold Coast Titans',
#    'NRL',
#    'NSW Police',
#    'NSW State of Origin',
#    'the Dally M Awards',
#    'the Gold Coast Titans'},
#   'Locations': {'Byron Bay',
#    'Byron Bay\n\n',
#    'NSW',
#    'New Zealand',
#    'the Gold Coast'},
#   'Dates': {'30'}},
#  '00092a7572e6e1d254a6d5f079c4d72d33435667.story': {'People': {'Alexis',
#    'Alexis  Boone',
#    'Alexis Boone',
#    'Capt.',
#    'Caroline Wugofski',
#    'Charlotte Boone',
#    'Clint',
#    'Clint Boone',
#    'David Cheplak',
#    'Dee Dee',
#    "Dee-Dee'",
#    'Don',
#    'Don Pyle',
#    'Eve Morrison',
#    'Grandparents Don',
#    'Howarth',
#    'Kaitlyn',
#    'Kaitlyn  Boone',
#    'Kaitlyn Boone',
#    'Katie',
#    'Lexi',
#    'Photographs',
#    'Pyle',
#    'Pyles',
#    'Randy Boone',
#    'Robert Howarth',
#    'Russ Davies',
#    'Sandra',
#    'Sandra Pyle',
#    "Sandra Pyle's",
#    'Sandy',
#    'Sandy Pyle',
#    "Sisters Alexis 'Lexi' Boone",
#    'Stacey Boone',
#    'Taylor Smith',
#    'Wes',
#    'Wesley',
#    'Wesley Boone',
#    'William McMullan'},
#   'Organizations': {'ATF',
#    'Anne Arundel County Fire Department',
#    'Boone',
#    'CNN',
#    'DailyMail.com',
#    'Davies',
#    'Facebook',
#    'Firearms',
#    'Medieval Times',
#    'Pyle',
#    'Randy',
#    'ScienceLogic',
#    'Target',
#    'The Baltimore Sun',
#    'WUSA9',
#    'the Baltimore Sun',
#    'the Bureau of Alcohol, Tobacco',
#    'the Naval Academy',
#    'the Washington Post',
#    "the county fire department's",
#    'the\xa0Bureau of Alcohol, Tobacco, Firearms and Explosives'},
#   'Locations': {'Annapolis',
#    'Baltimore',
#    'Baltimore County',
#    'Boone',
#    'Charlotte',
#    'Church Creek',
#    'Hannover',
#    'Maryland',
#    'Reston',
#    'Silicon Valley',
#    'Virginia',
#    'the Chesapeake Bay'},
#   'Dates': {'2005',
#    '2008',
#    '2012',
#    '56',
#    '6',
#    '7',
#    '8',
#    'eight',
#    'seven',
#    'six'}},
#  '000940f2bb357ac04a236a232156d8b9b18d1667.story': {'People': {'Casey',
#    'Casey Kasem',
#    "Casey Kasem's",
#    'Danny Deraney',
#    'Deraney',
#    'Jane Caffrey',
#    'Jean Kasem',
#    'Julie',
#    'Kasem',
#    'Kerri Kasem',
#    'Mike Kasem',
#    'Scott Thompson'},
#   'Organizations': {'CNN',
#    'Deraney PR',
#    'NBC',
#    'St. Anthony Hospital',
#    'Thompson',
#    'Twitter'},
#   'Locations': {'California',
#    'Gig Harbor',
#    'Kitsap County',
#    'Santa Monica',
#    'Washington'},
#   'Dates': {'2009'}},
#  '000994296459fb84cf26cf71a0c109c192758c11.story': {'People': {'Maddy',
#    'Maddy Andrew',
#    'Mike',
#    'Mrs Andrew',
#    'Paula',
#    'Paula Andrew',
#    'Stephen Hayes'},
#   'Organizations': {'6.7C', 'McDonald'},
#   'Locations': {'North Yorkshire', 'Scarborough'},
#   'Dates': {'12 and 14', '14 and 12', '43', '49', 'summer', 'winter'}},
#  '0009ca480b5c9d311cb43f852529e5e2a346fef5.story': {'People': {'Jennifer Thompson',
#    'Scott Mann'},
#   'Organizations': {'Dayton Daily News',
#    'De Graff',
#    'Riverside Local Schools School',
#    'Riverside Schools',
#    'Thompson'},
#   'Locations': {'Logan County', 'Ohio'},
#   'Dates': {'52'}},
#  '000beb8706bc2ad4c0c3040faf0ce54caa315454.story': {'People': {'Cyril',
#    'Irvine',
#    'Irvine Patnick',
#    'Lucy Osborne',
#    'Lynda',
#    'Matthew',
#    'Nick Clegg',
#    'Rosie Taylor',
#    'Sheffield Hallam',
#    'Suzanne'},
#   'Organizations': {'Hillsborough',
#    'Liverpool',
#    'OBE',
#    'Sheffield Jewish Representative Council',
#    'Sun',
#    'the Hillsborough Independent Panel’s'},
#   'Locations': {'Hillsborough',
#    'Kingfield Synagogue',
#    'Liverpool',
#    'Sheffield'},
#   'Dates': {'1980',
#    '1987 to 1997',
#    '30 December 2012',
#    '83',
#    'December 2012',
#    'December 30',
#    'Maccabi'}},
#  '000c5ee0134182945f21c67d4e8af59259cf77a2.story': {'People': {'Ar',
#    'Babysitter',
#    'Barry Watson',
#    'Beverly Mitchell',
#    'Camden',
#    'Catherine Hicks',
#    'Collins',
#    "D'Errico",
#    'David Gallagher',
#    "Donna D'Errico",
#    'Eric Camden',
#    'Faye Grant',
#    'Felicity',
#    'Grant',
#    'Ilene',
#    'Jessica Biel',
#    'Kate',
#    'Keri Russell',
#    'LAPD',
#    'Mackenzie Rosman',
#    'Rev Eric Camden',
#    'Stephen',
#    'Stephen Collins',
#    'Ted 2'},
#   'Organizations': {'Baywatch',
#    'Collins',
#    'MailOnline',
#    'Mix 104.1',
#    'NYPD',
#    'Playboy',
#    'TMZ',
#    'the Screen Actors Guild',
#    'the Special Victims Squad'},
#   'Locations': {'Boston',
#    'California',
#    'Los Angeles',
#    'Massachusetts',
#    'New York',
#    'Tarzana',
#    'pediphelia'},
#   'Dates': {'1996', '2007', '2012', 'the 1990s'}},
#  '000cd1ee0098c4d510a03ddc97d11764448ebac2.story': {'People': {'Dhakal',
#    'Kamal Prasad Kharel',
#    'Kharel'},
#   'Organizations': {'CNN',
#    'Uttarkhand',
#    'the Department of National Parks and Wildlife Conservation'},
#   'Locations': {'Baitadi district',
#    'Himalayas',
#    'India',
#    'Kathmandu',
#    'Maheshwor Dhakal',
#    'Nepal',
#    'the Baitadi district'},
#   'Dates': {'the age of 10'}},
#  '000cefd88b6f79d28c1fb220d5a3eed19514a462.story': {'People': {'Michelle Elliott'},
#   'Organizations': {'Daily Mail',
#    'Fragile Hearts',
#    'Infirmary',
#    'Leeds General Infirmary',
#    'NHS'},
#   'Locations': {'England', 'Leeds'},
#   'Dates': {'21 June 2013', 'April 2009', 'April 2013'}},
#  '000e009f6b1d954d827c9a550f3f24a5474ee82b.story': {'People': {'Barack Obama',
#    'Barbara Starr',
#    'Kyle',
#    'Kyle White',
#    "Kyle White's",
#    'Obama',
#    'White'},
#   'Organizations': {'Army',
#    'Army Special Forces',
#    'CNN',
#    'Chosen Company',
#    'NPR',
#    'National Public Radio',
#    'White',
#    'White House',
#    'the Congressional Medal of Honor Society'},
#   'Locations': {'Afghanistan',
#    'America',
#    'Charlotte',
#    'Iraq',
#    'North Carolina',
#    'Washington',
#    'White'},
#   'Dates': {'February 10', 'November 9, 2007', 'September 11, 2001'}},
#  '000e7f26e4dda517050bc09ee8d9a08a3b2334b7.story': {'People': {'Friend',
#    'Louise Eccles',
#    'Melissa',
#    'Melissa Reid',
#    "Melissa Reid's",
#    'Michaella',
#    'Michaella McCollum',
#    'Michaella McCollum Connolly',
#    'Miss\nHughes',
#    'Rebecca Hughes',
#    'Reid',
#    'William',
#    'William Reid'},
#   'Organizations': {'Dirandro', 'Scroll'},
#   'Locations': {'Dungannon',
#    'Glasgow',
#    'Ibiza',
#    'Lenzie',
#    'Lima',
#    'Michaella',
#    'Northern Ireland',
#    'Peru',
#    'San Antonio Bay',
#    'Spain'},
#   'Dates': {'19', '19 August 2013', '20', '20 August 2013', 'August 6'}},
#  '000f9a3513a610ff46580007e9ef7e9dd0bc9fef.story': {'People': {'David',
#    'Hobley',
#    'Mark David',
#    'Mary Buehrle',
#    'Ms Buehrle',
#    'Ms\xa0Buehrle',
#    'Pamela',
#    'Pamela Hobley',
#    "Pamela Hobley's",
#    'Patricia',
#    'Patricia Spencer'},
#   'Organizations': {'Oscoda High School',
#    'Oscoda Township Police Department',
#    'the National Center For Missing Children'},
#   'Locations': {'Michigan',
#    'Oscoda',
#    'Oscoda Township Police',
#    'Wilber Township'},
#   'Dates': {'15', '17', '2010', 'Halloween', 'October 31, 1969'}},
#  '000fdddcbfce58b56605f99e81c22c9b86ea4773.story': {'People': {'Castro',
#    'Castro\n ',
#    'Jill Reilly',
#    'Kathleen Castro',
#    'Kendrick Doidge',
#    'Mike Burke'},
#   'Organizations': {'Pensacola News Journal',
#    'Sacred Heart Hospital',
#    "Sheriff's Office",
#    'West Florida Hospital'},
#   'Locations': {'Escambia County',
#    "Escambia County Jail's",
#    'Florida',
#    'United States'},
#   'Dates': set()},
#  '0012256d996ac32c25dd1723785e567b3c063cab.story': {'People': {'Amanda',
#    'Amanda Knox',
#    "Amanda Knox's",
#    'Ashley',
#    'Carlo Dalla Vedova',
#    'Chris',
#    'Colin Sutherland',
#    'Curt Knox',
#    'Edda Mellas',
#    'James Terrano',
#    'John Kerry',
#    'Kercher',
#    'Knox',
#    'Markus Wiget',
#    'Meredith Kercher',
#    'Raffaele',
#    'Raffaele Sollecito',
#    'Raffaelle Sollecito',
#    'Rudy Guede'},
#   'Organizations': {'Amanda',
#    'Delaney',
#    'Knox',
#    "Meredith Kercher's",
#    'Scroll',
#    'Sollecito',
#    'State',
#    'the University of Washington',
#    'the West Seattle Herald'},
#   'Locations': {'Italy',
#    'New York',
#    'New York-',
#    'Rome',
#    'Seattle',
#    'US',
#    'Washington',
#    'West Seattle'},
#   'Dates': {'15',
#    '20',
#    '2007',
#    '2011',
#    '2013',
#    '27',
#    '28',
#    '30',
#    '40',
#    '52',
#    '54',
#    'the 2011',
#    'tomorrow'}},
#  '0012c075cf01cbdc30895f7a1568cf556225c0c3.story': {'People': {'Booked',
#    'Cheryl',
#    'David Gingras',
#    'Gringas',
#    'Jones',
#    'Nik Richie',
#    'Patricia Summe',
#    "Sarah\nJones's",
#    'Sarah Jones',
#    'William Bertelsman'},
#   'Organizations': {'ABC',
#    'Bengals',
#    'CDA',
#    'Cincinnati Bengals',
#    'Cincinnati.com',
#    'Daily Mail',
#    'Dixie Heights High School',
#    'U.S. Circuit Court of Appeals'},
#   'Locations': {'Bengal', 'Covington', 'Edgewood', 'Kentucky'},
#   'Dates': {'10 May 2012',
#    '1996',
#    '2009',
#    '2011-2012',
#    '26',
#    '55',
#    'June 27',
#    'between October 1 and December 31'}},
#  '00139ad128fc573dac7dfe4ce4921a07a408be60.story': {'People': {'Daoud',
#    'Eight Selborne',
#    'Habib',
#    'Ibrahim Abu Mohamed',
#    'Jamal Daoud',
#    'Johnson',
#    'Katrina Dawson',
#    'Mamdouh Habib',
#    'Man Haron Monis',
#    'Monis',
#    'Ms Dawson',
#    'Nabi Akram',
#    'Tori Johnson'},
#   'Organizations': {'Campsie',
#    'Hezbollah Australia',
#    'Islam',
#    'Islamic State',
#    'Labor',
#    'Lindt',
#    'Lindt Cafe',
#    "Martin Place's",
#    'Monis',
#    'News Corp',
#    'SPG',
#    'Society',
#    'State Protection Group',
#    'Telegraph',
#    'The Bomb Squad',
#    'The Daily Telegraph',
#    "the Man Haron Monis'",
#    'the\xa0Daily Telegraph'},
#   'Locations': {'Auburn',
#    'Australia',
#    'Fairfax',
#    'Granville',
#    'Guantánamo Bay',
#    'Melbourne',
#    'Pakistan',
#    'Sydney',
#    'the Islamic State'},
#   'Dates': {'2007', '2009', 'December 15', 'December 16'}},
#  '0013a4baaf65a56c857088f2e236bfbc080c88dc.story': {'People': {'Gregory Carro',
#    'Helen Collis',
#    'Helen Pow',
#    'Jesus',
#    'Jill Reilly',
#    'Karen Rosenbaum',
#    'Kevin Krim',
#    'Krim',
#    'Leo',
#    'Leo Krim',
#    'Lucia',
#    'Lucia Krim',
#    'Lulu',
#    'Marina Krim',
#    'Mrs Krim',
#    'Ms Leer-Greenberg',
#    'Nessie',
#    'Ortega',
#    'Valerie Van Leer-Greenberg',
#    'Yoselyn Ortega',
#    "Yoselyn Ortega's"},
#   'Organizations': {'CNBC',
#    'Krim',
#    'NY Daily News',
#    'New York Daily News',
#    'Rosenbaum',
#    'State Supreme Court',
#    'the NY Daily News'},
#   'Locations': {'America',
#    'Manhattan',
#    'Marina',
#    'Marina Krim',
#    'New York',
#    'New York City',
#    'Upper West Side',
#    'West Side'},
#   'Dates': {'13 August 2013', '2', '50', 'October 25', 'ages 6', 'six'}},
#  '001553918ab13ec4d55b7adf9175ba021fc1f7f8.story': {'People': {'Alma Silva Ramirez',
#    'Isaac Ramirez',
#    'Jesse Ramirez',
#    'Josh',
#    'Joshua',
#    'Joshua John',
#    'Joshua Lorenzo Ramirez',
#    'Joshua Ramirez',
#    'Krystal Ramirez',
#    'Ramirez',
#    'Saul Tarango',
#    'Steve Robson',
#    'Teresa Ramirez'},
#   'Organizations': {'Hereford Independent Schools District',
#    'KAMR-TV',
#    'Plainview High School',
#    'the Amarillo Globe-News'},
#   'Locations': {'Hereford', 'Houston', 'Texas'},
#   'Dates': {'15',
#    '1998',
#    '22 March 2013',
#    'March 10',
#    'March 12',
#    'March 17',
#    'March 8'}},
#  '00169039da88af38387c7da51d021868fcb6f26c.story': {'People': {'Alison Quanbrough',
#    'Copland',
#    'Edward Copland',
#    'Sam Webb',
#    'Steven Duffy'},
#   'Organizations': {'CPS', 'the Crown Prosecution'},
#   'Locations': {'Blackpool', 'Copland', 'Lancashire'},
#   'Dates': {'38', '6 November 2013'}},
#  '0016a36506199baae4cae50cd0758e45dddf87e7.story': {'People': {'Dave Fairbairn',
#    'David Fairbairn',
#    'Fairbairn',
#    'Geoff Knights',
#    'Gillian Taylforth',
#    'Kathy Beale',
#    'Knights',
#    'MailOnline',
#    'Taylforth'},
#   'Organizations': {'Bristol Crown Court',
#    'Broxbourne',
#    'Cambridgeshire',
#    'EastEnders'},
#   'Locations': {'Hertford', 'Hertfordshire', 'Taylforth', 'UK'},
#   'Dates': {'1.25am', '2003', '2009', '2012', 'February 23', 'February 7'}},
#  '0016bfe904685ce40f094b07c294c2065dd3a194.story': {'People': {'Jessica Jerreat\n\nStudents'},
#   'Organizations': {'Atlanta High School',
#    'Grady',
#    'Grady Hospital',
#    'Marcus Trauma Center',
#    'Therrell',
#    'Therrell High School',
#    'the Atlanta Journal Constitution'},
#   'Locations': {'Atlanta', 'Southwest Atlanta'},
#   'Dates': set()},
#  '0018963c6bfd060dbbbd6633a5655712d90643fb.story': {'People': {'Camilla Parker Bowles',
#    'Cutsem',
#    'Hugh van \nCutsem',
#    'Hunstanton',
#    'James Everett',
#    'Karen Melhado',
#    'Kate',
#    'Lynn',
#    'Neville Warnes',
#    'Prince Harry',
#    'Princess Margaret’s',
#    'Queen',
#    'Rebecca English',
#    'Sandringham',
#    'William'},
#   'Organizations': {'Anmer',
#    'Duchess',
#    'Grade II',
#    "King's",
#    'King’s',
#    'King’s Lynn',
#    'RAF Search',
#    'Royal',
#    'Sandringham Estate',
#    'The Sandringham Estate',
#    'West Norfolk Borough Council',
#    'the Anmer Mere Yacht Club',
#    'the Royal Family',
#    'the Virgin Church'},
#   'Locations': {'Anglesey',
#    'Cambridge',
#    'Cornwall',
#    'Edinburgh',
#    'Kensington Palace',
#    'Norfolk',
#    'Prince Charles',
#    'St Mary',
#    'Villager',
#    'West \nLondon',
#    'West London',
#    'York',
#    'north Norfolk'},
#   'Dates': {'10 January 2013',
#    '11 January 2013',
#    '1802',
#    '1862',
#    '1952',
#    '1972',
#    '1972 to 1990',
#    '1990',
#    '2001',
#    '2007',
#    '2017',
#    '82',
#    'December 10',
#    'March 11',
#    'every Christmas'}},
#  '00197f390e3dd2ce02eabb5fd44bb40b89b64389.story': {'People': {'BS',
#    "Denise 'Miki' Spies",
#    'Lydia Warren',
#    'Matt Lauer',
#    'Miki Spies',
#    'Missy',
#    'Spies',
#    'Sydney Spies',
#    'Westwood'},
#   'Organizations': {'American Horror House',
#    'Durango High School',
#    'Facebook',
#    'Spies',
#    'Syfy',
#    'The Durango Herald'},
#   'Locations': {'Colorado', 'Denver', 'Durango', 'Louisiana', 'Sydney'},
#   'Dates': {'14 August 2012', '18', '45', 'Halloween', 'June 24'}},
#  '0019f3f79be4536756ac180d154bf67294d0c9b6.story': {'People': {'Arshad Mahmood',
#    'Bevan',
#    'Graham Bevan',
#    'John Potter',
#    'Mahmood',
#    'Ms Qureshi',
#    'Shamalia Qureshi',
#    'W. Yorks'},
#   'Organizations': {'Bradford Crown Court',
#    'Daily Mail',
#    'Dell',
#    'Sony Ericsson',
#    'Three Sisters',
#    'the Three Sisters'},
#   'Locations': {'Haworth', 'West Yorks'},
#   'Dates': {'1 December 2011', '12 March 2013', '2007', '53'}},
#  '001a8b20279cb0b829cdb4fa8cd6997949c33f09.story': {'People': {'Artyon Pogosyan',
#    'Chris Parsons',
#    'Gazeta.ua',
#    'Jill Reilly',
#    'Makar',
#    'Maxim Prisyjnikov',
#    'Oksana',
#    'Oksana Makar',
#    'Pogosyan',
#    'Prisyjnikov',
#    'Simon Tomlinson',
#    'Surovitska',
#    'Tetyana Surovitska',
#    'Yanukovych',
#    'Yevgeniy Krasnoshek'},
#   'Organizations': {'Parliament',
#    'YouTube',
#    'the Hurriyet Daily News',
#    'the Kyiv Post'},
#   'Locations': {'Donetsk',
#    'Gazeta.ua',
#    'Kiev',
#    'Kyiv',
#    'Mykolayiv',
#    'Ukraine'},
#   'Dates': {'18', '21', '23', 'March 13', 'March 9'}},
#  '001b4673dbb3437282cd2ea58d9eca471e25780f.story': {'People': {'Andrey Lipatov',
#    'Anzhelina Vorontsova',
#    'Bolshoi Prima',
#    'Dmitrichenko',
#    'Filin',
#    'Galina Stepanenko',
#    'Gennady Yanin',
#    'Ivan',
#    'Lipatov',
#    'Nikolai Tsiskaridze',
#    'Pavel Dmitrichenko',
#    'Sergei Filin',
#    'Tsiskaridze',
#    'Yuri',
#    'Yuri Zarutsky',
#    'Zarutksy',
#    'Zarutsky'},
#   'Organizations': {'Ballet',
#    'Bolshoi Ballet',
#    'Bolshoi Theatre',
#    'Facebook',
#    'Filin',
#    'Lipatov',
#    'RIA Novosti',
#    'The Bolshoi Theatre\n\nBallet',
#    "the Bolshoi Theatre's"},
#   'Locations': {'Bolshoi', 'Hollywood', 'Moscow', 'Russia', "Swan Lake's"},
#   'Dates': {'42', 'March 2011'}},
#  '001b6dccba3ab0efb4296e04669bac42f5bee886.story': {'People': {'Adrienne',
#    'Adrienne Spates',
#    'Jacob',
#    'Jacob Spates',
#    'Jill Reilly',
#    'Jocob',
#    'Jones',
#    'Joshua',
#    'Langham',
#    'Max Langham',
#    'Ms\n Spates',
#    'Toddler'},
#   'Organizations': {"A'zhari",
#    "A'zhari Jones",
#    "A'zhiah",
#    "Le Bonheur Children's Hospital",
#    'Le Bonheur Children’s Hospital',
#    'the Department of Child Services',
#    'the Regional Medical Center'},
#   'Locations': {'Memphis', 'Virginia'},
#   'Dates': {'2011', '22 October 2013', 'April 2012', 'January 24, 2011'}},
#  '001b8ecda7b31fff8ab04a99a0455336477f09a1.story': {'People': {'Baby',
#    'Balthazar',
#    'Clare',
#    'Florence Hegoburu',
#    'Fraser',
#    'Hawke',
#    'Iris',
#    'Isaac',
#    'Ms Hawke',
#    'Xynthia Hawke',
#    'Yannick Balthazar'},
#   'Organizations': {'Anaesthetist Helga Wauters',
#    'Belgian Helga Wauters',
#    'Haygrove School',
#    'Wauters',
#    'the University of London Institute'},
#   'Locations': {'Briton',
#    'France',
#    'North Petherton',
#    'Orthez',
#    'Paris',
#    'Pau',
#    'Somerset',
#    'South',
#    'UK',
#    'Ustaritz',
#    'the French Pyrenees'},
#   'Dates': {'28',
#    '30',
#    '33',
#    '45',
#    '56',
#    '61',
#    'September 26',
#    'September 30',
#    'up to'}},
#  '001c9b4f4f1f431b85bae0abaadf4e7666064f35.story': {'People': {'Dianne',
#    'Dianne Staniforth',
#    'Julie Baird',
#    'Michelle Witham',
#    'Mrs Baird',
#    'Mrs Staniforth',
#    'Paul',
#    'Paul McCandless',
#    'Staniford',
#    'Staniforth'},
#   'Organizations': {'Coroner',
#    'Pinderfields Hospital',
#    'Sheffield Hospital',
#    'the Department of Work and Pensions',
#    'www.samaritans.org'},
#   'Locations': {'Chesterfield', 'Derbyshire', 'Wakefield', 'West Yorkshire'},
#   'Dates': {'15', '51', 'April 22', 'October 2012'}},
#  '001db2e0e30e54bc5effda388ffb51425d018caf.story': {'People': {'Blackwood',
#    'Brian Blackwood',
#    'Buddha',
#    'Htut Ko Ko Lwin',
#    "Htut Ko Ko Lwin's",
#    'Insein',
#    'Myat Nandar',
#    'Phil Robertson',
#    'Philip Blackwood',
#    'Tun Thurein',
#    'V Gastro',
#    'Ye Lwin'},
#   'Organizations': {'Blackwood',
#    'Facebook',
#    'Fairfax Media',
#    'Human Rights Watch',
#    'Religious Department',
#    'VGastro',
#    'VGastro Bar',
#    'the New Zealander'},
#   'Locations': {'Asia', 'Myanmar', 'New Zealand', 'Yangon'},
#   'Dates': {'2011', '26', '32', '40', 'a further'}},
#  '001dc91a62bad5263259a1d664c821cb1e700f27.story': {'People': {'Baldwin',
#    'Craiglist',
#    'David Baldwin',
#    'James Jones Jr.',
#    'Jonathon Myles',
#    'Jones',
#    'Jordan Baker',
#    'Kaylnn Ruthenberg'},
#   'Organizations': {'ABC News',
#    'Brown Middle School',
#    'Clark Atlanta',
#    'Clark Atlanta University',
#    'Craigslist',
#    'Fickett Elementary School',
#    'Marietta Police',
#    'UPS',
#    'iPhone',
#    'the Clark Atlanta University',
#    'the HBCU Rising Cares Mentoring'},
#   'Locations': {'Atlanta', 'Central Florida', 'Daytona Beach'},
#   'Dates': {'18', '19', '21'}},
#  '001e8bda2f7ab73bf81314c1639a97dae2751703.story': {'People': {'Angela Corey',
#    'Corey',
#    'Craig Sonner',
#    'Cristian Fernandez',
#    'David',
#    'Dee Dee',
#    'Dennis Baxley',
#    'Episcopalian',
#    'Fernandez',
#    'George Zimmerman',
#    "George Zimmerman's",
#    'Hal Uhrig',
#    'Joran Van Der Sloot',
#    'Martin',
#    'Norman Wolfinger',
#    'Sean Hannity',
#    'Sunny Hostin',
#    'Trayvon',
#    'Trayvon Martin',
#    'Zimmerman'},
#   'Organizations': {'CNN',
#    'Fox News',
#    'Martin notices Zimmerman',
#    'Target',
#    'Zimmerman',
#    'the 4th Circuit',
#    'the 4th Judicial Circuit'},
#   'Locations': {'Duval County',
#    'Florida',
#    'Jacksonville',
#    'New York',
#    'Northeast Florida',
#    'Seminole County Courthouse'},
#   'Dates': {'April 10', 'February 26'}},
#  '001f7a255ce06e0bc3a8cffb94fc0019ba0f2f34.story': {'People': {'Rafael',
#    'Rafael Max'},
#   'Organizations': {'Diva', 'Express', 'The Huffington Post'},
#   'Locations': {'Italvino', 'UK'},
#   'Dates': {'1948', '89'}},
#  '001fb37cf8a91dd358548d409d1ea09f4120ab6f.story': {'People': {'Andrew Gilligan',
#    'Boris Johnson',
#    'Brian Holt',
#    'Dave',
#    'Francis Golding',
#    'James',
#    'Johnson',
#    'Michelle Baharier',
#    'Ms Baharier',
#    'Murza',
#    'Muzira',
#    'Richard',
#    'Richard Muriza',
#    'Richard Muzira',
#    'Roger William De Klerk',
#    'Roger de Klerk',
#    'Sam Webb',
#    'Venera Minakhmetova',
#    'Vigil'},
#   'Organizations': {'BBC London 94.9',
#    'CoolTan',
#    'CoolTan Arts',
#    'Extra',
#    'Forest Hill',
#    'MAD',
#    'Mental Health and Disability',
#    'The Parliamentary Advisory Council for Transport Safety',
#    'Venera Minakhmetova',
#    'the Bank of America',
#    'the Metropolitan Police Service'},
#   'Locations': {'Aldgate',
#    'Bow',
#    'Camberwell',
#    'Camden',
#    'Croydon',
#    'Dulwich',
#    'East Croydon',
#    'London',
#    'South London',
#    'Whitechapel',
#    'south \n'},
#   'Dates': {'2011',
#    '2012',
#    '43',
#    '60s',
#    '62',
#    '69',
#    'November 2013',
#    'November 5th',
#    'early 60s',
#    'past fortnight'}},
#  '0021fe8d65bd0d6d76d5fefba2ac02f0c48a43f4.story': {'People': {'Anne Donnelly',
#    'Anthony Moschetto',
#    'Chmela',
#    'Christi Paul',
#    'James Chmela',
#    'James Kalamaras',
#    'Kalamaras',
#    'Moschetto',
#    'Moshetto',
#    'Randy Zelin',
#    'Zelin'},
#   'Organizations': {'CNN', 'WCBS'},
#   'Locations': {'Long Island', 'Nassau County District Court', 'New York'},
#   'Dates': {'41', '43', '54'}},
#  '0022a8a7afe47ac14e7ed51c38f629c866661e38.story': {'People': {'Chris Gleeson',
#    'Christine',
#    'Christine Lee',
#    'Dennis',
#    'John Lowe',
#    'Lowe',
#    'Lucy',
#    'Lucy Lee',
#    'Mark Dennis QC',
#    'Mrs Lee',
#    'Stacey Banner',
#    'Susanna Wilson'},
#   'Organizations': {'Guildford Crown Court',
#    'Lowe',
#    'Lowe later',
#    "Lowe's",
#    'Toyota'},
#   'Locations': {'Farnham', 'Surrey', 'Tilford'},
#   'Dates': {'2013', '40', '82'}},
#  '0022b77434a498d0bf38836caa3ec8c071f624f6.story': {'People': {'20:16 EST',
#    'Betsy Randolph',
#    'Bruce Peoples',
#    'Custer\nCounty Sheriff',
#    'Debbie McManaman',
#    'Foss Lake',
#    'Jimmy',
#    'Jimmy Allen Williams',
#    'Jimmy Williams',
#    'Kim Carmichael',
#    'Leah Gail Johnson',
#    'Ms\nCarmichael',
#    'Ms Carmichael',
#    'Randolph',
#    'Thomas \nMichael Rios',
#    'Thomas Michael Rios',
#    'Wayne',
#    'Williams'},
#   'Organizations': {'Camaro',
#    'Chevrolet',
#    'Daily Mail',
#    'Highway Patrolmen',
#    'KFOR',
#    'KWEY',
#    'Newsnine.com',
#    'Oklahoma Bureau',
#    'Oklahoma Highway Patrol',
#    'the \nOklahoma Highway Patrol',
#    'the Oklahoma Highway Patrol'},
#   'Locations': {'Beckham County',
#    'Custer County',
#    'Elk City',
#    'Foss Lake',
#    'Oklahoma',
#    'Sayre',
#    'Washita County'},
#   'Dates': {'16',
#    '17 September 2013',
#    '18',
#    '18 September 2013',
#    '1950',
#    '1950s',
#    '1969',
#    '1970',
#    '2003',
#    'Nov. 20, 1970',
#    'November 10 1970',
#    'November 20, 1970',
#    'the 1950s',
#    'the early 1960s',
#    'the late 1950s or early 1960s'}},
#  '002360f910e8b59949ff31b49af0a7b8126593d3.story': {'People': {'Esme',
#    'Esme Smith',
#    'Farnham',
#    'Hugo Gye',
#    'Jon Savell',
#    'Mark',
#    'Mark Smith',
#    'Savell',
#    'Sian',
#    'Smith',
#    'Smiths',
#    'Waterloo'},
#   'Organizations': {'Aldershot',
#    'All Hallows Catholic School',
#    'BMW',
#    'CCTV',
#    'Charing Cross',
#    'Facebook',
#    'Joint Warfare Centre',
#    'Nato',
#    'Surrey Police',
#    'Twitter',
#    'the Metropolitan Police'},
#   'Locations': {'Afghanistan',
#    'Esme',
#    'Farnham',
#    'London',
#    'North London',
#    'Northern Ireland',
#    'Stavanger',
#    'Surrey',
#    'Waterloo'},
#   'Dates': {'14',
#    '23 September 2013',
#    '24 September 2013',
#    'September 12',
#    'September 19',
#    'September 20',
#    'September 23'}},
#  '00238f16261b335618b065b5a4e5433de3c14615.story': {'People': {'Abraham',
#    'Abraham Cumberbatch',
#    'Abraham Cumberbatch - seen',
#    'Abraham Parry',
#    'Ann',
#    'Benedict',
#    'Benedict Cumberbatch',
#    "Benedict Cumberbatch's",
#    'Bussa',
#    'Cumberbatchs',
#    'Joshua',
#    'Oscar',
#    'Sherlock',
#    'Solomon Northup',
#    'Steven',
#    'Steven Tempro',
#    'Timothy Carlton',
#    'Tracie Bennett',
#    'Wanda',
#    'Wanda Ventham',
#    'Willaim Pitt',
#    'William Ford',
#    'William Pitt',
#    'gong'},
#   'Organizations': {'Cleland Plantation',
#    'Cumberbatch',
#    'Parish Church',
#    'Taunton School'},
#   'Locations': {'Barbados',
#    'Britain',
#    'Caribbean',
#    'Cleland\n\n',
#    'Devon',
#    'Northup',
#    'Saint Andrew',
#    'Solomon Northup',
#    'UK'},
#   'Dates': {'1750',
#    '1816',
#    '1820',
#    '1830s',
#    '1838',
#    '1985',
#    '19th century',
#    '2006',
#    '2012',
#    '2013',
#    '38',
#    'February 22',
#    'the 18th and 19th centuries',
#    'the early 18th century',
#    'the late 17th century'}},
#  '00a3121ae106ce18379649be9d61faaf9b885ea7.story': {'People': {'Bain',
#    'Barack Obama',
#    'Callista',
#    'Gingrich',
#    'Mitt Romney',
#    'Newt',
#    'Newt Gingrich',
#    'Palin',
#    'Rick Perry',
#    'Rick Santorum',
#    'Romney',
#    'Ron Paul',
#    'Santorum',
#    'Sarah Palin'},
#   'Organizations': {'Bain',
#    'Bain Capital',
#    'Columbia',
#    'Fox News',
#    'GOP',
#    'Gallup',
#    'House',
#    'Venture',
#    'White House',
#    'the Myrtle Beach Convention Center'},
#   'Locations': {'Alaska',
#    'Columbia',
#    'Florence',
#    'Iowa',
#    'Myrtle Beach',
#    'New Hampshire',
#    'South Carolina',
#    'U.S.',
#    'West Columbia'},
#   'Dates': {'2008', 'some quarters'}},
#  '00a6c0823ba92e5a055d90133e8b66fa9028c2d7.story': {'People': {'Barack Obama',
#    'Chuck Hagel',
#    'Frank-Walter Steinmeier',
#    'Gennady Kernes',
#    'Hagel',
#    'Michael Bociurkiw',
#    'Obama',
#    'Ponomarev',
#    'Putin',
#    'Sergei Shoigu',
#    'Stella Khorosheva',
#    'Vladimir Putin',
#    'Vyacheslav Ponomarev'},
#   'Organizations': {'CNN',
#    'Commerce',
#    'Defense',
#    'Defense Ministry',
#    'Kernes',
#    'NATO',
#    'OSCE',
#    'Pengaton',
#    'Pentagon',
#    'Shoigu',
#    'State',
#    'The European Union',
#    'The White House',
#    'the Council of the European Union',
#    'the Defense Ministry',
#    'the Organization for Security and Co',
#    'the White House'},
#   'Locations': {'Donetsk',
#    'Eastern Europe',
#    'Europe',
#    'Germany',
#    'Kharkiv',
#    'Kiev',
#    'Manila',
#    'Moscow',
#    'Philippines',
#    'Russia',
#    'Slavyansk',
#    'Sweden',
#    'The United States',
#    'U.S.',
#    'Ukraine',
#    'the United States'},
#   'Dates': set()},
#  '00a7132b9c9a646852ac4a606acb71e3a6acb8c6.story': {'People': set(),
#   'Organizations': {'CNN', 'LCD', 'Sony'},
#   'Locations': {'Bravia', 'Japan', 'TOKYO', 'Tokyo'},
#   'Dates': {'2007',
#    '2008',
#    'December 31',
#    'March 31',
#    'the quarter',
#    'third-quarter'}},
#  '00b3cebdfa5caccbddb4c701689e2dfddd89a3d4.story': {'People': {'Andy Williams',
#    'Cappadocia',
#    'Chichén Itzá',
#    'Lao',
#    'Mérida',
#    'Trekking'},
#   'Organizations': {'CNN',
#    'Innsbruck',
#    'The Harbin Ice Festival',
#    'Topdeck Travel',
#    'Tyrol',
#    'UNESCO World Heritage Site',
#    'Volubilis',
#    'the Laos & Cambodia Explorer'},
#   'Locations': {'Africa',
#    'Anatolia',
#    'Angkor',
#    'Arusha National Park',
#    'Atlantic',
#    'Beijing',
#    'Buenos Aires',
#    'California',
#    'Cambodia',
#    'Cancún',
#    'Chile',
#    'China',
#    'Costa Rica',
#    'Essaouira',
#    'Fez',
#    'Forbidden City',
#    'Gallipoli',
#    'Harbin',
#    'Ice',
#    'Istanbul',
#    'Kirchdorf',
#    'Laos',
#    'Las Vegas',
#    'Luang Prabang',
#    'Marrakech',
#    'Morocco',
#    'Mount Kilimanjaro',
#    'Northeast China',
#    'Patagonia',
#    'Sahara',
#    'Salzburg',
#    "San Francisco's",
#    'Sand',
#    'Santiago',
#    'Souks',
#    'St. Nick',
#    "St. Nick's",
#    'Tulúm',
#    'Turkey',
#    'Uxmal',
#    "Xi'an",
#    'Yosemite',
#    'the Grand Canyon',
#    'the Mekong River',
#    'the North Pole',
#    'the Western United States',
#    'the Yucatán Peninsula'},
#   'Dates': {'2013',
#    '2014',
#    'Christmas',
#    'December 18-29',
#    'December 19-28',
#    'December 21-28',
#    'December 21-30',
#    'December 21-January 3',
#    'December 21-January 4',
#    'December 22-31',
#    'December 23-January',
#    'December 23-January 2',
#    'December 28-January 4',
#    'under 40'}},
#  '00bab59ff44f83281a07ff92439089c58c2f54bb.story': {'People': {'Anne Grace',
#    "Anne Grace's",
#    'Arlene Salac',
#    'Bryan Lanzello',
#    'Grace',
#    'Lois Farella',
#    "Lois Farella's",
#    'MailOnline',
#    'Victoria Wellman'},
#   'Organizations': {'CBS', 'FAA', 'the Federal Aviation Administration'},
#   'Locations': {'Long Island', 'Valley Stream', 'Valley Streams'},
#   'Dates': {'11 September 2012', 'Fall'}},
#  '00d48bf5089a093edf12ef5f3836780e97be6be0.story': {'People': {'Lucas Leiva',
#    'Mark Shearan',
#    'Match',
#    'Neymar',
#    'Santos',
#    'Will Neymar'},
#   'Organizations': {'Arsenal',
#    'CNN',
#    'London Police',
#    'Metropolitan Police',
#    'Premier League',
#    'SFA',
#    'The Scottish Football Association',
#    'the Brazilian Football Federation'},
#   'Locations': {'Brazil',
#    'England',
#    'Europe',
#    'Kentaro',
#    'Liverpool',
#    'London',
#    'Neymar',
#    'Scotland'},
#   'Dates': {'19', '2014'}},
#  '00f2dcbaf64df265065f3ef314f5bbc17e6950ca.story': {'People': {'15:18 EST',
#    'Anchory',
#    'Edward Snowden',
#    'James Clapper'},
#   'Organizations': {'Associated Press',
#    'Daily Mail Reporter',
#    'Journal',
#    'NSA',
#    'Reuters',
#    'Reuters Reporter',
#    'Surveillance',
#    'The\nJournal',
#    'the National Security Agency',
#    'the Wall Street Journal'},
#   'Locations': {'Bad Aibling',
#    'Fort Meade',
#    'Germany',
#    'Maryland',
#    'Maui',
#    'U.S.',
#    'the United States'},
#   'Dates': {'2011', '21 August 2013'}},
#  '0189e00e90723bc2449a3522557b4edfa54ebf52.story': {'People': {'Bunker',
#    'Sandra Zouzalova',
#    'Simon Tomlinson'},
#   'Organizations': {'Jalta',
#    'Jalta Hotel',
#    'Tours',
#    "the Czech Republic Ministry of Defence\n\nPrague's",
#    'the Ministry of Defence'},
#   'Locations': {'Prague'},
#   'Dates': {'1989',
#    '1998',
#    '2 December 2013',
#    'between 1954 and 1958',
#    'the 1980s'}},
#  '069f469ad0d105a36345ad93637b6c10771fb8f3.story': {'People': {'Andy',
#    'Andy Murray',
#    "Andy Murrey's",
#    'Angelique Kerber',
#    'Aspinal Marylebone',
#    'Burberry',
#    'Dimitrov',
#    'Grigor Dimitrov',
#    'Kate',
#    'Katy Winter',
#    'Kim',
#    'Kim Sears',
#    'Maria',
#    'Maria Sharapova',
#    'Murray',
#    'Patrick Mouratoglou',
#    'Scot',
#    'Serena',
#    'Serena Williams -',
#    'Sharapova',
#    'Sticking',
#    'Williams',
#    'Wimbledon\n\nKim'},
#   'Organizations': {'Centre Court',
#    'Sharapova',
#    'Sugarpova',
#    'the All England Club',
#    'the Royal Box'},
#   'Locations': {'Cambridge',
#    'Highbury',
#    'Islington',
#    'Marylebone',
#    'Murray',
#    'North London',
#    'US',
#    'Wimbledon'},
#   'Dates': {'2004',
#    '2012',
#    '2013',
#    '25',
#    '32',
#    'summer',
#    'the quarter',
#    'the quarter-finals'}},
#  '09b9fda5fe70b96e95d9899f080dccb0e0dcd77a.story': {'People': {'Charlie Webster',
#    'Ched Evans',
#    'Evans',
#    'Farrugia',
#    'Jeffrey Farrugia',
#    'Natasha Massey',
#    'Olympian Jessica Ennis-Hill',
#    'Paola',
#    'Stephen (Vaughan',
#    'Stephen Vaughan'},
#   'Organizations': {'Ched',
#    'Club',
#    'Evans\n\nSheffield United',
#    'HFC',
#    'Oldham Athletic',
#    'Sky Sports News',
#    'The Maltese Premier League',
#    'Tranmere Rovers'},
#   'Locations': {'Hartlepool United',
#    'Hibs',
#    'Malta',
#    'Scotland',
#    'Sheffield United',
#    'UK'},
#   'Dates': {'#', '2011', '2012'}},
#  '0a031d23cc9696d34b418d6b8d46fb2be777db23.story': {'People': {'Lamagni',
#    'Theresa Lamagni'},
#   'Organizations': {'NHS', 'PHE', 'Public Health England'},
#   'Locations': {'England'},
#   'Dates': {'Between 12 to 48 hours', 'the 1960s', 'two to eight'}},
#  '0a045dcc5d3fddad8617a17db4fb36e490921b75.story': {'People': {'Adam Levy',
#    'Barack Obama',
#    'Ben Carson',
#    'Bill Hartzell',
#    'Bobby Jindal',
#    'Bush',
#    'Carly Fiorina',
#    'Carson',
#    'Chris Christie',
#    'Christie',
#    'Chuck Grassley',
#    'Cruz',
#    'Donald Trump',
#    'Eric Rosenthal',
#    'Ernie Rudolph',
#    'Fiorina',
#    'Hillary',
#    'Hillary Clinton',
#    'Huckabee',
#    'Jeb Bush',
#    'Joni Ernst',
#    'Marco Rubio',
#    'Michael Patomson',
#    'Mike Huckabee',
#    'Mitt',
#    'Mitt Romney',
#    'Obama',
#    'Obamacare',
#    'Palin',
#    'Rand Paul',
#    'Rick Perry',
#    "Rick Perry's",
#    'Rick Santorum',
#    'Santorum',
#    'Scott Walker',
#    'Steve King',
#    "Steve King's",
#    'Ted Cruz',
#    'Trump',
#    'Walker'},
#   'Organizations': {'CNN',
#    'Christie',
#    'Citizens United',
#    'Common Core',
#    'Congress',
#    'Council Bluffs',
#    'DES MOINES',
#    'Fox News',
#    'Hewlett Packard',
#    'Hoyt Sherman Place',
#    'Huckabee',
#    'IRS',
#    'ISIS',
#    "King's",
#    'The Hawkeye State',
#    'the Iowa Freedom Summit'},
#   'Locations': {'Arkansas',
#    'Cedar Rapids',
#    'Dallas County',
#    'Des Moines',
#    'Iowa',
#    'Iowans',
#    'Jersey',
#    'New Jersey',
#    'Pennsylvania',
#    'Texas',
#    'U.S.',
#    'Washington',
#    'Wisconsin',
#    'the State of the Union'},
#   'Dates': {'1877', '2008', '2011', '2012', '2016'}},
#  '0a0a007398ab02d4bd3c1ef9e034f567afa76b2c.story': {'People': {'Boris Johnson',
#    'Edmund King',
#    'Gordon Brown'},
#   'Organizations': {'AA', 'the Daily Mail', 'the European Commission'},
#   'Locations': {'Britain', 'London'},
#   'Dates': {'2001', 'the 1990s'}},
#  '0a0a1a0e94aac65f2b50815050dfaccf521dda35.story': {'People': {'David Coggon',
#    'Paul Elliott'},
#   'Organizations': {'Health\n Research',
#    'Imperial College London',
#    'MTHR',
#    'The Mobile Telecommunications',
#    'The University of Oxford',
#    'WHO',
#    'the Norwegian Expert Committee',
#    'the World Health Organisation'},
#   'Locations': {'UK'},
#   'Dates': {'2011', '2012'}},
#  '0a0a4c90d59df9e36ffec4ba306b4f20f3ba4acb.story': {'People': {'Carl Levin',
#    'Dean Obeidallah',
#    'Dianne Feinstein',
#    'John Krasinski',
#    'John McCain',
#    'Krasinski',
#    'Matt Damon',
#    'Obeidallah',
#    'Osama bin Laden',
#    'Peter Bergen',
#    'bin Laden'},
#   'Organizations': {'CNN',
#    'Energy in Depth',
#    'Sony Pictures',
#    'the Independent Petroleum Association of America and Energy in Depth'},
#   'Locations': {'Hollywood', 'U.S.', 'Washington'},
#   'Dates': set()},
#  '0a0d524f9f21f6132b91422e00b575080bb7c4a6.story': {'People': {'Karen Lorre',
#    'Ms Daedone',
#    'Ms Lore',
#    'Ms Lorre',
#    'Nicole Daedone',
#    'OM',
#    'Pooja Lakshmin',
#    'Rachel',
#    'Sarah Griffiths',
#    'Yoga',
#    'orgasms'},
#   'Organizations': {'Medical Daily', 'Playmate', 'Rutgers University'},
#   'Locations': {'California', 'London', 'Long Beach', 'San Francisco'},
#   'Dates': {'51', '8 August 2013', '9 August 2013', 'the age of 25'}},
#  '0a167e1b287070c1ac577400309a55d499939d2c.story': {'People': {'Britons',
#    'Cameron',
#    'David Cameron',
#    'Rafal Trzaskowski',
#    'Trzaskowski'},
#   'Organizations': {'BBC Newsnight', 'Cameron', 'EU', 'the European Union'},
#   'Locations': {'Britain', 'Europe', 'Poland', 'UK'},
#   'Dates': set()},
#  '0a1ef61e85845fc03a2aad06aabad8d34e0b36ad.story': {'People': {'Barack Obama',
#    'Biden',
#    'Carney',
#    'Enrique Pena Nieto',
#    'Harper',
#    'Harry Reid',
#    'Jay Carney',
#    'Joe Biden',
#    'Keystone',
#    'Mitch McConnell',
#    'Nancy Pelosi',
#    'Obama',
#    'Peña Nieto',
#    'Stephen Harper'},
#   'Organizations': {'Congress',
#    'Democratic Party',
#    'House',
#    'Keystone',
#    'Keystone XL',
#    'Pacific nations',
#    'Senate',
#    'State Department',
#    'Trans-Pacific Partnership',
#    'White House',
#    "the North American Leaders' Summit",
#    'the White House'},
#   'Locations': {'Alberta',
#    'Canada',
#    'Maryland',
#    'Mexico',
#    'Toluca',
#    'U.S.',
#    'the Gulf of Mexico',
#    'the Rio Grande',
#    'the United States'},
#   'Dates': set()},
#  '0a23ba95558bc16e21815b6d1297b60c0e78caaa.story': {'People': {'Transcript'},
#   'Organizations': {'CNN Student News',
#    'the CNN Student News Roll Call',
#    'the Common Core State Standards'},
#   'Locations': {'France', 'Indonesia', 'mascot'},
#   'Dates': {'January 13, 2015'}},
#  '0a3bcbacfb0040800aba71a470c0194d0d7c5a62.story': {'People': {'Adam Levine',
#    'Anders Fogh Rasmussen',
#    'Andrew Hoehn',
#    'Chris Lawrence',
#    'Madeleine Albright',
#    'Mikhail Saakashvili',
#    'Obama',
#    'Rasmussen',
#    'Saakashvili',
#    'Sarah Harting'},
#   'Organizations': {'CNN',
#    'Congress',
#    'European Union',
#    'NATO',
#    'NATO Ivo Daalder',
#    'RAND',
#    'START',
#    'State',
#    'U.S. Senate',
#    'the RAND Corporation',
#    'the U.S. Congress'},
#   'Locations': {'Afghanistan',
#    'Asia',
#    'Europe',
#    'Georgia',
#    'Lisbon',
#    'Moscow',
#    'Portugal',
#    'Portugual',
#    'Russia',
#    'The United States',
#    'U.S.',
#    'the United States'},
#   'Dates': {'2008',
#    '21st century',
#    'between 2011 and 2014',
#    'the 21st century',
#    'the end of'}},
#  '0a459eb9164b45589795af3ad7c7f6dd22685af0.story': {'People': {'Kevin McCloud',
#    'Suzanna'},
#   'Organizations': {'Britons',
#    'Channel 4',
#    'Grand Designs',
#    'Happiness Architecture Beauty'},
#   'Locations': {'Britain', 'Burton', 'Elizabethan', 'Europe', 'Swindon', 'UK'},
#   'Dates': {'1999', '52', '55'}},
#  '0a471293143e542e3f3ff00265bcadfbc68bda25.story': {'People': {'Al Assad',
#    'Alan Grayson',
#    'Anthony Cordesman',
#    'Assad',
#    'Barack Obama',
#    'Bashaar al-Nasr',
#    'Bashar al-Assad',
#    'Buck McKeon',
#    'Charlie Rose',
#    'Chuck',
#    'Chuck Hagel',
#    'Cordesman',
#    'Denis McDonough',
#    'Ed Husain',
#    'George Tenet',
#    'John Kerry',
#    'Kerry',
#    'Obama',
#    'Sarin',
#    'William Polk',
#    'al-Assad'},
#   'Organizations': {'CBS',
#    'CIA',
#    'CNN',
#    'CSIS',
#    'Congress',
#    'Defense',
#    'Joint Intelligence Organization',
#    'NATO',
#    'PBS',
#    'State',
#    'State of the Union',
#    'Syrian Coalition',
#    'Syrian Islamic Liberation Front',
#    'The U.S. State Department',
#    'The United Nations',
#    'The White House',
#    'U.N.',
#    'White House',
#    'al Qaeda',
#    'al-Assad',
#    'al-Nusra Front',
#    'the Center for Strategic and International Studies',
#    'the Council on Foreign Relations',
#    'the U.N. Independent International Commission of Inquiry',
#    'the U.S. Defense Department'},
#   'Locations': {'Adra',
#    'Aleppo',
#    'America',
#    'Atlantic',
#    'Britain',
#    'California',
#    'D-Florida',
#    'Damascus',
#    'France',
#    'Iraq',
#    'Russia',
#    'Syria',
#    'U.S.',
#    'the United States'},
#   'Dates': {'1967', 'August 21'}},
#  '0a4a9488b5e913b1de866446d53073d113688768.story': {'People': {'Ms Lamb',
#    'Sue Lamb'},
#   'Organizations': {'ANZ',
#    'ATM',
#    'BOQ',
#    'Bank of Queensland',
#    'Daily Mail',
#    'the Gold Coast Bulletin'},
#   'Locations': {'Australia', 'Gold Coast', 'Labrador', 'New Zealand'},
#   'Dates': {'2012', '49'}},
#  '0a5c5a5f92c35ec03cd42feee53474d4164cbf33.story': {'People': {'Abe',
#    'Henry',
#    'Junko Ogura',
#    'Keith Henry',
#    'Shinzo Abe',
#    'Yoshihide Suga'},
#   'Organizations': {'Asia Strategy',
#    'CNN',
#    'Cabinet',
#    'Sendai',
#    "the Fukui District Court's",
#    "the Kansai Electric Power Company's",
#    'the Nuclear Regulation Authority'},
#   'Locations': {'Fukui Prefecture',
#    'Fukushima',
#    'Japan',
#    'Kagoshima Prefecture',
#    'Takahama',
#    'Tokyo'},
#   'Dates': {'2011'}},
#  '0a60266f622680ec18cc85219f9f7c76c4e10205.story': {'People': {'Andrew Montford',
#    'Bengtsson',
#    'Benny Peiser',
#    'Ed Miliband',
#    'Henderson',
#    'John Shade',
#    'Lawson',
#    'Lennart Bengtsson',
#    'McCarthy',
#    'McCarthyism',
#    'Nigel Lawson',
#    'Prof Bengtsson'},
#   'Organizations': {'GWPF',
#    'Global Warming Policy Foundation',
#    "Global Warming Policy Foundation's",
#    'Group',
#    'Labour',
#    'Miliband',
#    'The Global Warming Policy Foundation',
#    'the House of Lords',
#    'the Meteorology department',
#    "the US Government's",
#    'the University of Reading'},
#   'Locations': {'US'},
#   'Dates': {'2009', '79', 'November 2009', 'the late 20th Century'}},
#  '0a60d5c98e767514e6431e2b61a900ccba178741.story': {'People': set(),
#   'Organizations': {'Daily Mail',
#    'PIX 11 News',
#    'PS Marcato',
#    'PS Marcato Elevator Company',
#    'the New York Times'},
#   'Locations': {'Long Island',
#    'Manhattan',
#    'New York City Department of Building',
#    'Queens',
#    'Upper West Side'},
#   'Dates': {'1903', '2003-2013', 'April 2014'}},
#  '0a61cc5c304b3d78070eea0d2686da69d56552f0.story': {'People': {'Britons',
#    'Cameron',
#    'David Cameron',
#    'Duncan Smith',
#    'Iain Duncan Smith',
#    'James Chapman'},
#   'Organizations': {'Cabinet',
#    'EU',
#    'Labour',
#    'The Work and Pensions',
#    'non-EU',
#    'the Home Office'},
#   'Locations': {'Britain', 'Continent', 'Madrid', 'UK'},
#   'Dates': {'1 July 2011', 'Between 1997 and 2010'}},
#  '0a6e74e3116ca8246fa2d09929b59746973721f2.story': {'People': {'Arpaio',
#    'Brooke Anderson',
#    'Bull Connor',
#    'Doug Gross',
#    'Joe Arpaio',
#    'Paco Fabian',
#    'Phil Brown',
#    'Watch Arpaio'},
#   'Organizations': {'Arpaio',
#    'CNN',
#    'FBI',
#    'Fox Reality Channel',
#    "Fox Reality's",
#    'Maricopa Co.',
#    'Toughest Sheriff',
#    "the U.S. Justice Department's"},
#   'Locations': {'Alabama',
#    'America',
#    'Arizona',
#    'Birmingham',
#    'California',
#    'HOLLYWOOD',
#    'Maricopa',
#    'Maricopa County',
#    'Phoenix',
#    'U.S.'},
#   'Dates': {'1960s', '76'}},
#  '0a75c4f2a8a1468afbc2f2b1591d134c3cea30ec.story': {'People': {'Sylwester Wardega',
#    "Sylwester Wardega's",
#    'Wardega'},
#   'Organizations': {'YouTube'},
#   'Locations': {'Poland', 'Warsaw'},
#   'Dates': {'26'}},
#  '0a7d822a4d9f7269255b194d01a3503e7e207c7f.story': {'People': {'Balls',
#    'David Cameron',
#    'Ed Balls',
#    'George Osborne',
#    'Labour',
#    'Liz Pearce',
#    'Osborne',
#    'Prince William',
#    'Tudor'},
#   'Organizations': {'BPF',
#    'Bank',
#    'Bank of England',
#    'CBI',
#    'EEF',
#    'Labour',
#    'NHS',
#    'RAF Valley',
#    'Search and Rescue',
#    'The British Retail Consortium',
#    'The Duke of',
#    'Treasury',
#    'the British Business Bank',
#    'the British Property Federation',
#    'the Federation of Small Businesses'},
#   'Locations': {'Anglesey', 'Birmingham', 'Britain', 'Cambridge', 'UK'},
#   'Dates': {'1601', '2011', '2012', 'April 1'}},
#  '0a80d772e87c235cb633a19107483e345d6ef46a.story': {'People': {'Cora Thiel',
#    'Oliver Ullrich',
#    'Panspermia',
#    'Plos One',
# ...
#  'cc2856da355ca43c4f55f7d5d6760d0a5b263edb.story': {'People': {'Allen West',
#    'Anders Fogh Rasmussen',
#    'Barack Obama',
#    'Blake Farenthold',
#    'James Inhofe',
#    'Jason Chaffetz',
#    'Kerry Bentivolio Tim Scott',
#    'Michael Burgess',
#    'Obama',
#    'Obamacare',
#    'Palin',
#    "Rosie O'Donnell",
#    'Sarah Palin',
#    'Scott',
#    'Tim Scott',
#    'Tom Coburn',
#    'Tom Tancredo',
#    'Vladimir Putin',
#    'Whoopi Goldberg'},
#   'Organizations': {'Border Patrol',
#    'Breitbart.com',
#    'Congress',
#    'DOJ',
#    'GOP',
#    'IRS',
#    'NATO',
#    'NSA',
#    'Palin',
#    'Sportsman Channel',
#    'TMZ',
#    'The Hollywood Reporter',
#    'The South Dakota Republican Party',
#    'White House',
#    'the U.S. Senate',
#    'the White House'},
#   'Locations': {'Alaska',
#    'America',
#    'California',
#    'Central America',
#    'Colorado',
#    'D.C.',
#    'Florida',
#    'Hollywood',
#    'Iraq',
#    'Michigan',
#    'Murrieta',
#    'Oklahoma',
#    'South Carolina',
#    'Texas',
#    'U.S.',
#    'Utah',
#    'Washington'},
#   'Dates': {'2009', '2011', '2012'}},
#  'cc7388549854539e807948d84fc37a7b9b20d61b.story': {'People': {'Adams',
#    'Alyssa Smith',
#    'Chris Low',
#    'Damian Andrade',
#    'Diana Adams',
#    'Fred',
#    "John D'Agostini",
#    'Scott McLean',
#    'Tim Flaherty',
#    'Wayne Allen Huntsman'},
#   'Organizations': {'Apple Hill',
#    'El Dorado Cal Fire',
#    'Forest Service',
#    'Tahoe National Forest',
#    'The King Fire',
#    'The National Weather Service',
#    'University of California',
#    'the California Department of Forestry',
#    'the California Department of Forestry and Fire Protection',
#    'the California Department of Forestry and Fire Protection\n\nContainment',
#    'the King Fire',
#    'the Sequoia National Forest Cobra',
#    'the Tahoe National Forest'},
#   'Locations': {'Auburn',
#    'Berkeley',
#    'California',
#    'El Dorado',
#    'El Dorado County',
#    'French Meadows Reservoir',
#    'Fresno',
#    'Lake Tahoe',
#    'Las Vegas',
#    'Mosquito',
#    'Nevada',
#    'Placerville',
#    'Pollock Pines',
#    'Reno',
#    'Rockville',
#    'Roseville',
#    'Sacramento',
#    'Sparks Marina',
#    'Tuolumne-Calaveras',
#    'US',
#    'the King Fire'},
#   'Dates': {'37', 'September 13', 'between January 1 and September 20'}},
#  'ccca8cc860b0f58a2ed643d016c022e66536ec42.story': {'People': {'Claire',
#    'Claire Nugent',
#    'Hitler',
#    'Jill Reilly',
#    'Mosquito',
#    'Nigel',
#    'Nigel Morter',
#    'Nod'},
#   'Organizations': {'Allied',
#    "Bomber Command's",
#    'De Havilland',
#    'Handley Page Halifaxes',
#    'London \nMetropolitan University',
#    'Ministry of \nFood',
#    'No 171 Squadron',
#    'No 274 Maintenance Unit',
#    'North Creake',
#    'RAF',
#    'RAF Bomber Command',
#    'RAF North Creake',
#    'SOS',
#    'Stirling',
#    'the Holkham Estate'},
#   'Locations': {'Britain',
#    'Chaff',
#    'Halifax',
#    'Norfolk',
#    'Normandy',
#    'North Creake',
#    'Stirling'},
#   'Dates': {'1930s',
#    '1950s',
#    '7 November 2012',
#    '8 November 2012',
#    'May 1944',
#    'November 23 1943',
#    'October 2011',
#    'September 1944',
#    'September 1947',
#    'the spring of 1944'}},
#  'd305159fb796ddc13ad5dbb31c04d8a7d5c6268f.story': {'People': {'Amber',
#    'Bruce Johnson',
#    'Chan',
#    'Frieden',
#    'Jeremy Writebol',
#    'Joanne Liu',
#    'Kent Brantly',
#    'Margaret Chan',
#    'Mrs Writebol',
#    'Nancy Writebol',
#    'Thomas Frieden',
#    'Vincent Martin'},
#   'Organizations': {'AP Photo/Courtesy',
#    'CDC',
#    'ELWA',
#    'Elwa',
#    'Emory University Hospital',
#    'FAO',
#    'Medecins Sans Frontieres - MSF',
#    'SIM',
#    'SIM USA',
#    'Serving In Mission',
#    'Serving in Mission',
#    'Sierra Leone',
#    'U.N.',
#    'WHO',
#    'Without Borders',
#    'World Health Organization',
#    'hazmat',
#    'the Centers for Disease Control and Prevention',
#    'the U.N. FAO',
#    'the U.N. Food and Agriculture Organization'},
#   'Locations': {'Africa',
#    'Atlanta',
#    'Central Africa',
#    'Charlotte',
#    'Congo',
#    'Emory',
#    'Georgia',
#    'Guinea',
#    'Ivory Coast',
#    'Liberia',
#    'Monrovia',
#    'Nigeria',
#    'North Carolina',
#    'U.S.',
#    'West Africa'},
#   'Dates': {'59', 'August 21', 'Earlier on'}},
#  'd415537ea8a0a765e786ef0bb423090e5b8ab391.story': {'People': {'George Osborne',
#    'Jeremy Blackburn',
#    'Stephen Herring',
#    'Stuart Adam'},
#   'Organizations': {'Duncan Economics',
#    'Exchequer',
#    'Labour',
#    'Nationwide',
#    'The Institute of Directors’',
#    'The Office for National Statistics',
#    'Treasury',
#    'the Institute for Fiscal Studies',
#    'the Office for National Statistics',
#    'the Royal Institution of Chartered Surveyors'},
#   'Locations': {'Britain', 'London', 'North', 'Northern Rock', 'UK'},
#   'Dates': {'2000',
#    '2003',
#    '2008',
#    '2013',
#    'August 2007',
#    'Between April and July',
#    'July 2013',
#    'March 2009'}},
#  'dbf45ddb53f321bfbc9f72f5443f232e0f64e3a9.story': {'People': {'Alex Davey',
#    'Burton',
#    'Carragher',
#    'Chelsea',
#    'Fankaty Dabo',
#    'Fikayo Tomori',
#    'Harry Wilson',
#    'Jamie Carragher',
#    'Jerome Sinclair',
#    'Joe Riley',
#    'Krisztian Adorjan',
#    'Mike Marsh',
#    'Raheem Sterling',
#    'Ro-Shaun Williams',
#    'Robbie',
#    'Robbie Fowler',
#    'Rodolfo Borrell',
#    'Sinclair',
#    'Steven Gerrard',
#    'Stuart Webber'},
#   'Organizations': {'Chelsea',
#    'Chester\n\nSinclair',
#    'Inter Milan',
#    'Liverpool',
#    'Liverpool\n\nPosition:',
#    'Ludogorets Razgrad',
#    'Manchester United',
#    'Premier League',
#    'Rosenborg',
#    'Sinclair',
#    'Sky Sports',
#    'UEFA Youth League',
#    'the Liverpool Echo',
#    'the Three Lions',
#    'the UEFA Youth League'},
#   'Locations': {'Anfield',
#    'Birmingham',
#    'Chester',
#    'England',
#    'France',
#    'Hawthorns',
#    'Italy',
#    'Liverpool',
#    'Madrid',
#    "Manchester United's",
#    'Melwood',
#    'Morocco',
#    'Tomori',
#    'Wales',
#    'West Brom'},
#   'Dates': {'2011-2012',
#    '2012',
#    'April 2013',
#    'October 2011',
#    'Second-half',
#    'September 1996',
#    'between the ages of 10 and 14',
#    'second-half',
#    'september 2012',
#    'the first-half',
#    'the under 18, under 19 and under 21',
#    'under 16 and under 17'}},
#  'ddc527f81c55302c6972a61df336a4ce37619e16.story': {'People': {'Eric Holthaus',
#    'Freezing',
#    'Golfer Chris Wood',
#    'Golfer Rory McIlroy',
#    'Hunter Mahan',
#    'Luke Donald',
#    'McIlroy',
#    'Rickie Fowler',
#    'Ricky Fowler',
#    'Rory McIlroy',
#    'Snow',
#    'Steve Nolan',
#    'Tiger Woods'},
#   'Organizations': {'5C',
#    'Bristol',
#    'the New York Times',
#    'the Ritz Carlton Club',
#    'the US National Weather Service'},
#   'Locations': {'Alaska',
#    'Arizona',
#    'Dove Mountain',
#    'Qatar',
#    'Tucson',
#    'UK',
#    'the Tortolita Mountain'},
#   'Dates': {'1894',
#    '20 February 2013',
#    '21 February 2013',
#    'February 27 2011',
#    'January 30 2002'}},
#  'df8071d652d84b27d411ac00c85a028d7e72fc7c.story': {'People': {'Barcelona',
#    'David de Gea',
#    'David de Gea\n\nLuis Suarez',
#    'Ed',
#    'Fernando Macias',
#    'Gareth Bale',
#    "Gareth Bale's",
#    'Lucas Silva',
#    'Luis Suarez',
#    'Manuel Godoy',
#    'Martin Odegaard',
#    'Silva'},
#   'Organizations': {'AS',
#    'Barcelona',
#    'CAS',
#    'Committee',
#    'EU',
#    'FIFA',
#    'ITC',
#    'International Transfer Certificate',
#    'La Liga',
#    'Manchester United',
#    'RFEF',
#    'RSTP',
#    'Real Madrid',
#    'solidarity',
#    'the\xa0Court of Arbitration for Sport'},
#   'Locations': {'Barajas',
#    'Barcelona',
#    'Cordoba',
#    'Liverpool',
#    'Madrid',
#    'Man United\xa0',
#    'Milan',
#    'Rayo Vallecano',
#    'River Plate',
#    'Spain',
#    'Venezuela'},
#   'Dates': {'14 in 2013',
#    '2009',
#    '2012',
#    '2013',
#    '2015',
#    'between 2009 and',
#    'the age of 12',
#    'under 18'}},
#  'e6b851358e3c2e5391b42141518630bba1bf1eb7.story': {'People': {'Everton',
#    'Howard',
#    'Steve Johnson',
#    'Tim',
#    'Tim Howard'},
#   'Organizations': {'Community',
#    'Croxteth Sports Centre',
#    'Everton',
#    'the Championship Division',
#    'the WFA National League'},
#   'Locations': {'Medicash', 'U.S'},
#   'Dates': set()},
#  'e8e0c65bd956546ea81e8d2bd81f6aaec94831d5.story': {'People': {'Borini',
#    'Connor',
#    'Connor Wickham',
#    'Fabio Borini',
#    'Gus Poyet',
#    'Poyet',
#    'Sunderland'},
#   'Organizations': {'Premier League', 'West Ham’s'},
#   'Locations': {'Liverpool',
#    'Sunderland',
#    'West Brom',
#    'West Bromwich',
#    'West Ham'},
#   'Dates': set()},
#  'ec92eeb018ae9348d93ef9b2dd80cc81fed3c2eb.story': {'People': {'Alan Irvine',
#    'Irvine',
#    'Joleon',
#    'Joleon Lescott',
#    'Lescott'},
#   'Organizations': {'Baggies',
#    'Lescott',
#    'Premier League',
#    'QPR',
#    'Stoke',
#    'West Bromwich Albion'},
#   'Locations': {'Manchester City', 'West Brom', "West Brom's", 'West Ham'},
#   'Dates': {'32', 'the busy Christmas period'}},
#  'f4044e398c7a68b1af43995677bdf80ac0657014.story': {'People': {'Andres Iniesta',
#    'Angel Di Maria',
#    'Arjen Robben',
#    'Cristiano Ronaldo',
#    "Gareth Bale's",
#    'James Rodriguez',
#    'Lionel Messi',
#    'Luis Suarez',
#    'Manuel Neuer',
#    'Neuer',
#    'Robben',
#    'Ronaldo',
#    'Thomas Muller'},
#   'Organizations': {'AS Monaco',
#    "Ballon D'Or",
#    'Bayern',
#    'Bayern Munich',
#    "Bayern Munich's",
#    'Champions League',
#    'Champions League for Real Madrid\n\n',
#    'Chelsea',
#    'Real Madrid',
#    'Sevilla\n\nSave',
#    'UEFA',
#    'the Champions League'},
#   'Locations': {'Argentina',
#    'Atletico Madrid',
#    'Barcelona',
#    'Bayern',
#    'Brazil',
#    'Bundesliga',
#    'Colombia',
#    'Diego Costa',
#    'Europe',
#    'Germany',
#    'Holland',
#    'Lahm',
#    'Liverpool',
#    'Madrid',
#    'Monaco',
#    'Spain',
#    'Uruguay'},
#   'Dates': {'2010-11',
#    '2011',
#    '2011-12',
#    '2012-13',
#    '2013-14',
#    '2014-15',
#    '5)Philipp',
#    'August 28',
#    'seven to 10'}},
#  'fe3dd15fe1b59a96fe4162553279dd1ed263d121.story': {'People': {'Fishman',
#    'Lauri Love',
#    'Paul Fishman'},
#   'Organizations': {'Army',
#    'CNN',
#    'EPA',
#    'NASA',
#    'the Environmental Protection Agency'},
#   'Locations': {'England', 'New Jersey', 'U.S.', 'Virginia'},
#   'Dates': {'28'}},
#  'feb0bd824bfa76f71edccd48c1f167b42a210c8b.story': {'People': {'Andros Townsend',
#    'Christian Eriksen',
#    'Erik Lamela',
#    'Erika Lamela',
#    'Jeffery Schlupp',
#    'Lamela',
#    'Lamela leaps',
#    'Leandro Ulloa',
#    'Leicester',
#    'Ryan Shawcross',
#    'Spurs'},
#   'Organizations': {'Roma',
#    'Spurs',
#    'Spurs 1-0',
#    'Tottenham',
#    'the Evening Standard',
#    'the FA\xa0Cup'},
#   'Locations': {'Blades', 'Leicester', 'Sheffield United', "Stoke City's"},
#   'Dates': {'2008', '2013'}},
#  'ff0f9801334d6f97b2b05c390a7313cfc3e64140.story': {'People': {'Heath Montgomery',
#    'Kari Bowen'},
#   'Organizations': {'Coors Field',
#    'Front Range',
#    'Frontier Airlines',
#    'National Weather Service',
#    'Northeast',
#    'The National Weather Service',
#    'US Airways',
#    'the San Francisco Giants'},
#   'Locations': {'Aurora',
#    'Boulder',
#    "Castle Rock's",
#    'Colorado',
#    'Colorado Springs',
#    'Delaware',
#    'Denver',
#    'Florida',
#    'Idaho',
#    'Kent County',
#    'Lafayette',
#    'Marydel',
#    'Midwest',
#    'New Jersey',
#    'New Mexico',
#    'New York',
#    'New York City',
#    'Northeast',
#    'Orlando',
#    'Pennsylvania',
#    'Philadelphia',
#    'Red Feather Lakes',
#    'The West Coast',
#    'United States',
#    'Virginia',
#    'West',
#    'the West Coast'},
#   'Dates': set()},
#  'ff18a63fb30d6b696e725f2d4009ddd13a4146a2.story': {'People': {'Aquatica',
#    'Beto Carrero World',
#    'Florida10',
#    'Hot Park',
#    'Waterbom Bali'},
#   'Organizations': {'Aquaventure Waterpark',
#    'Disney',
#    'Germany3',
#    'Hollywood Studios',
#    'Islands of Adventure',
#    'Rust',
#    'Traveler',
#    'TripAdvisor',
#    'Universal',
#    'Universal Studios Singapore',
#    'World'},
#   'Locations': {'Adeje',
#    'Anaheim',
#    'Animal Kingdom',
#    'Aquiraz',
#    'Bahamas',
#    'Beach Park',
#    'Blizzard Beach',
#    'Brazil',
#    'Brazil3',
#    'California',
#    'Discovery Cove',
#    'Dubai',
#    'Europa Park',
#    'Florida',
#    'Germany',
#    'Kuta',
#    'Magic Kingdom',
#    'Orlando',
#    'Paradise Island',
#    'Penha',
#    'PortAventura Park',
#    'Rio Quente',
#    'Salou',
#    'Sentosa Island',
#    'Siam Park',
#    'Singapore9',
#    'Spain',
#    'Tenerife',
#    'Typhoon Lagoon',
#    'United Arab Emirates9'},
#   'Dates': set()},
#  'ff6bb1e8a47fdd6c32f14201b7aa50dd7720a9ca.story': {'People': {'Alan Clarke',
#    'Ben Broadbent',
#    'David Cameron',
#    'Jubilee',
#    'Kate Middleton',
#    'Mervyn',
#    'Mervyn King',
#    'Prince William',
#    'Rick Dewsbury',
#    'Spencer Dale'},
#   'Organizations': {'Bank',
#    'Bank Holiday',
#    'Bank of England',
#    'Eurozone',
#    'Goldman Sachs',
#    'Q3',
#    'Royal',
#    'Royal Wedding',
#    'the House of Lords Economic Affairs Committee'},
#   'Locations': {'Britain', 'Harrods', 'London', 'Scotiabank', 'UK'},
#   'Dates': {'2009',
#    '2012',
#    'June 4 and',
#    'May 2012',
#    'Q4',
#    'between April and May',
#    'quarterly',
#    'the fourth quarter of 2011',
#    'the quarter',
#    'the second quarter',
#    'the third quarter',
#    'three successive quarters',
#    'two consecutive quarters'}},
#  'ff95cbf06bc9e4b2b0c4bb7b46794e63cacaa834.story': {'People': {'Carolyn Wu',
#    'Proview Shenzhen',
#    'Proview Taipei',
#    'Tim Cook'},
#   'Organizations': {'Apple',
#    'Apple Inc.',
#    'LCD',
#    'Lawsuit',
#    'Proview',
#    'Proview International',
#    'Proview International Holdings Ltd.',
#    'Shenzhen Proview Technology',
#    'The Apple Store',
#    'Xinhua',
#    'iPad',
#    'the Municipal Intermediate People’s Court'},
#   'Locations': {'Beijing',
#    'California',
#    'China',
#    'Cupertino',
#    'Hong Kong',
#    'Shenzhen',
#    'Southern China',
#    'Taiwan',
#    'U.S.'},
#   'Dates': {'2001', '2009', 'as early as 2000'}},
#  'ffcbb4742e7df96316bda9385d8ec14078aa5b3f.story': {'People': {'Cynthia Kelly',
#    'George Holliday',
#    'Holliday',
#    'John Davies',
#    'King',
#    'Koon',
#    'Laurence Michael Powell',
#    'Pete Wilson',
#    'Powell',
#    'Reginald Denny',
#    'Rodney King',
#    "Rodney King '",
#    "Rodney King's",
#    'Stacey Koon',
#    'Stanley Weisberg',
#    'Theodore Briseno',
#    'Timothy Wind',
#    'Wind'},
#   'Organizations': {'KTLA',
#    "King's",
#    'LAPD',
#    'National Guard',
#    'Superior Court',
#    'The U.S. District Court'},
#   'Locations': {'Briseno',
#    'Florence',
#    'Los Angeles',
#    'Los Angeles County',
#    'Normandie',
#    'Simi Valley',
#    'South Central',
#    'U.S.'},
#   'Dates': {'1991',
#    '1992',
#    'April 16, 1993',
#    'April 19, 1994',
#    'April 2012',
#    'April 29, 1992',
#    'April 30-May 4, 1992',
#    'August 4, 1992',
#    'August 4, 1993',
#    'February 25, 1993\n\n',
#    'June 1, 1994',
#    'June 17, 2012',
#    'March 15, 1991',
#    'March 3, 1991',
#    'March 4, 1991',
#    'March 7, 1991',
#    'May 1, 1992',
#    'May 10, 1991',
#    'November 26, 1991'}},
#  'ffd480659edff188a04fbd2114b0f63113669407.story': {'People': {'Putin',
#    'Vladimir Putin'},
#   'Organizations': set(),
#   'Locations': {'Crimea', 'Moscow', 'Russia', 'Sochi', 'Ukraine'},
#   'Dates': {'the high 80s'}},
#  'fffb9fbf64cc936c10ecef14b684ac67b6b6b9e7.story': {'People': {'Obama',
#    'Rick Scott',
#    'Roy LaHood'},
#   'Organizations': {'AVE',
#    'Acela Express',
#    'Amtrak',
#    'CEI',
#    'EU',
#    'FRA',
#    'HEMU-430X',
#    'Korea Train Express',
#    'Railway Gazette',
#    'Shinkansen',
#    'Transportation',
#    'White House',
#    'the Competitive Enterprise Institute',
#    'the European Union',
#    'the Federal Railroad Administration',
#    'the International Union of Railways',
#    'the White House'},
#   'Locations': {'Baltimore',
#    'Beijing',
#    'Boston',
#    'California',
#    'China',
#    'Connecticut',
#    'Delaware',
#    'Europe',
#    'Florida',
#    'France',
#    'Jacksonville',
#    'Japan',
#    'Korea',
#    'Maryland',
#    'Massachusetts',
#    'Miami',
#    'Midwest',
#    'New England',
#    'New Haven',
#    'New Jersey',
#    'New York',
#    'New York City',
#    'Ohio',
#    'Orlando',
#    'Pennsylvania',
#    'Philadelphia',
#    'Rhode Island',
#    'San Diego',
#    'San Francisco',
#    'Santiago de Compostela',
#    'Southeast',
#    'Spain',
#    'Tampa',
#    'U.S.',
#    'United States',
#    'Washington',
#    'Wisconsin',
#    'Wuhan',
#    'the Gulf Coast',
#    'the Pacific Northwest',
#    'the United States'},
#   'Dates': {'2010', '2011'}}}

# %%
# 导出为 Excel 文件
df = pd.DataFrame(retrieved_documents)
df_transposed = df.transpose()

excel_path = '/Users/irisgong/Desktop/ISE540 Text Analytics/project/retrieved.xlsx'
df_transposed.to_excel(excel_path, index=False)

# 打印成功消息
print(f'DataFrame已成功导出到 {excel_path}')
# Out:
# DataFrame已成功导出到 /Users/irisgong/Desktop/ISE540 Text Analytics/project/retrieved.xlsx

# %%
ground_truth
# Out:
# {'0000800d9058217f6509d7e63ad475e2de0da611.story': {'People': {'Barmaid Laura Baty',
#    'Carer Kim Taylor',
#    'Charlie Pugsley',
#    'Evelyn Raywood',
#    'Fire chiefs',
#    'Jake',
#    'Jean Booth',
#    'Kim Taylor',
#    'Laura Baty',
#    'London fire chiefs',
#    'Philip Le Shirley',
#    'Richard Spillett',
#    'Yasin Patel'},
#   'Organizations': {'Ford Mondeo',
#    'Prestige Vaping， the Royal Society for the Prevention of Accidents'},
#   'Locations': {'Chesterfield',
#    'Derbyshire',
#    'East London',
#    'Leicester',
#    'Manchester',
#    'North Yorkshire',
#    'Richmond',
#    'Wythenshawe Hospital'},
#   'Dates': set()},
#  '0001d4ce3598e37f20a47fe609736f72e5d73467.story': {'People': {'Cameron Atfield',
#    'Charles Vacca',
#    'Jim McCabe',
#    'Liz Matthews',
#    'Mike Murphy',
#    'Mohave County Sheriff',
#    'Nikki Bateman',
#    'Sam Scarmardo',
#    'nine-year-old girl',
#    'shooting instructor'},
#   'Organizations': {'Arizona shooting range',
#    'John Clayton Show',
#    'Las Vegas Review Journal',
#    'MSNBC',
#    'NBC News'},
#   'Locations': {'Arizona',
#    'Bullets and Burgers',
#    'Lake Havasu City',
#    'Las Vegas',
#    'Nevada',
#    'White Hills'},
#   'Dates': set()},
#  '0002067d13d3ca304e0bc98d04dde85d4091c55e.story': {'People': {'Bert',
#    'Joe Smales',
#    'Mr Justice Butterfield',
#    'Niall Pawson',
#    'Paul Maxwell',
#    'Rochdale',
#    'Tameside'},
#   'Organizations': {'Greater Manchester Police', 'Leeds Crown Court'},
#   'Locations': {'Rochdale town centre', 'Wakefield', 'West Yorkshire'},
#   'Dates': {'1996', '1998', '2/22/2014', '2011', 'June 1996'}},
#  '000219931d2c3aae55dc2acdc5f690d0c112ab17.story': {'People': {'Constable Mark Hopkins',
#    'Fraser Wylie',
#    'Jack Roland Crown',
#    'Judith Paynes',
#    'Nat Carey',
#    'Simon Gledhill',
#    'Una Crown',
#    'William Morris',
#    'retired postmistress'},
#   'Organizations': {'Bedfordshire',
#    'Cambridgeshire and Hertfordshire professional standards department',
#    'Home Office'},
#   'Locations': {'Cambridgeshire', 'Huntingdon', 'Wisbech'},
#   'Dates': {'1/13/2013', 'June 2013'}},
#  '00022dbfa44ccdb94c1dc06938047e258076cf75.story': {'People': {'Chris Brooke',
#    'David Gordon',
#    'Paul Smith',
#    'Richard Woolfall'},
#   'Organizations': {'Hull Crown Court', 'Taliban'},
#   'Locations': {'East Hull'},
#   'Dates': {'2012-09-03 00:00:00'}},
#  '0002b1d590aa4d2f6f000a03947317b6dc4e5c18.story': {'People': {'Alexander Litvinenko',
#    'Anatoli',
#    'Andrei Lugovoy',
#    'Ben Emmerson QC',
#    'Dmitry Kovturn',
#    'Hugh Davies',
#    'Kovtun',
#    'Lugovoy',
#    'Marina Litvinenko',
#    'Mark Duell',
#    'Robert Owen',
#    'Russian spy',
#    'Ryan Kisiel',
#    'Vladimir Putin'},
#   'Organizations': {'British intelligence',
#    'Crown Prosecution Service',
#    'Her Majesty’s Government',
#    'High Court',
#    'KGB',
#    'MI5',
#    'MI6',
#    'Scotland Yard',
#    'The Daily Mail',
#    'The Metropolitan Police Service'},
#   'Locations': {'Grosvenor Square',
#    'London hotel',
#    'Millennium\nHotel',
#    'Scotland'},
#   'Dates': {'2006', '9/20/2012', 'November 1'}},
#  '0002b6c22d2efa3af4971f9d515178bb89e31934.story': {'People': {'Gary Kelly',
#    'Marcel Maden',
#    'Mark Duell'},
#   'Organizations': {'Greater Manchester Police', 'Manchester Crown Court'},
#   'Locations': {'Greater Manchester', 'Salford'},
#   'Dates': {'2013-03-14 00:00:00'}},
#  '0002c17436637c4fe1837c935c04de47adb18e9a.story': {'People': {'Blaga Stancheva',
#    'Deputy U.S. Marshals',
#    'Dorothee',
#    'Dorothee Burkhart',
#    'Edward Nordskog',
#    'Gunther Meilinger',
#    'Harry Burkhart',
#    'Los Angeles County Deputy District Attorney',
#    'Los Angeles District Attorney',
#    'Nordskog',
#    'Sean Carney',
#    'Steve Cooley',
#    'Upinder Kalra'},
#   'Organizations': {'CNN',
#    'Canadian government',
#    'Los Angeles Superior Court'},
#   'Locations': {'British Columbia',
#    'Canada',
#    'Frankfurt',
#    'Germany',
#    'Hollywood',
#    'Los Angeles',
#    'Los Angeles jail',
#    'Neukirchen',
#    'Sherman Oaks',
#    'United States',
#    'Vancouver',
#    'West Hollywood'},
#   'Dates': {'2010',
#    '2011',
#    'January 24',
#    'March of 2010',
#    'between 2000 and 2006'}},
#  '00030c0cba08a5b361fd3ecb4dbf232da8269c55.story': {'People': {'Barbara Roberts',
#    'Graham Smith',
#    'Honey'},
#   'Organizations': {'Withington Hedgehog Hospital Trust'},
#   'Locations': {'Manchester'},
#   'Dates': {'2001', '2025', '6/23/2012'}},
#  '0003ad6ef0c37534f80b55b4235108024b407f0b.story': {'People': {'Ari Abdallah Morales',
#    'Cody Ray Smith',
#    'Jose Carlos Montano',
#    'Manuel Ortega',
#    'Marcelles James Peter',
#    'Mark Gagan',
#    'Salvador Rodriguez'},
#   'Organizations': {'CNN', 'Richmond Police'},
#   'Locations': {'California',
#    'Contra Costa County Superior Court',
#    'Richmond',
#    'San Pablo',
#    'northern California high school campus',
#    'the Richmond High School'},
#   'Dates': set()},
#  '00050e5dbf398963ad40cb6ff81c918c932cc809.story': {'People': {'Blamed Sylvester',
#    'Edd Filiti',
#    'Jennifer Flavin',
#    'Mark Berry',
#    'Mike Larkin',
#    'Sasha Czack',
#    'Sylvester Stallone',
#    'Toni Ann'},
#   'Organizations': {'Los Angeles Police Department',
#    'New York Post',
#    'RadarOnline',
#    'Rambo'},
#   'Locations': {'Comic Con', 'Hollywood Hills'},
#   'Dates': {'16 July 2012', '1985', '1990', '1996', '7/6/2023'}},
#  '000513feba4745611532547b50df128c5ea564e4.story': {'People': {'Antonio French',
#    'Darren Wilson',
#    'Jay Nixon',
#    'Michael Brown',
#    'Thomas Jackson'},
#   'Organizations': {'ABC News', 'Ferguson police', 'National Guard'},
#   'Locations': {'Ferguson', 'West Florissant'},
#   'Dates': set()},
#  '0005c9808410ba585973fdf2eaa0d1bb9070546e.story': {'People': {'Beccy Rochow',
#    'Greg Bird'},
#   'Organizations': {'Australian team',
#    'Four Nations',
#    'NRL',
#    'NSW State of Origin',
#    'New Zealand',
#    'The Gold Coast Titan',
#    'the Dally M Awards'},
#   'Locations': {'Byron Bay', 'NSW coastal town'},
#   'Dates': set()},
#  '00092a7572e6e1d254a6d5f079c4d72d33435667.story': {'People': {'Alexis (Lexi) Boone',
#    'Caroline Wugofski',
#    'Charlotte Boone',
#    'Clint Boone',
#    'David Cheplak',
#    'Don Pyle',
#    'Eve Morrison',
#    'Randy',
#    'Robert Howarth',
#    'Russ Davies',
#    'Sandy Pyle',
#    'Stacey Boone',
#    'Taylor Smith',
#    'Wesley (Wes) Boone',
#    'William McMullan',
#    'aitlyn (Katie) Boone'},
#   'Organizations': {"ATF's Baltimore field office",
#    'Anne Arundel County Fire',
#    'Anne Arundel County Fire Department',
#    'Baltimore Sun',
#    'Bureau of Alcohol',
#    'CNN',
#    'DailyMail.com',
#    'Firearms',
#    'Police Departments',
#    'ScienceLogic',
#    'The Baltimore Sun',
#    'Tobacco',
#    'WUSA9',
#    'Washington Post',
#    'the Naval Academy'},
#   'Locations': {'Annapolis',
#    'Chesapeake Bay',
#    'Childs Point Road',
#    'Church Creek',
#    'Hannover',
#    'Maryland',
#    'Reston',
#    'Silicon Valley',
#    'Virginia'},
#   'Dates': {'2005', '2008', '2012'}},
#  '000940f2bb357ac04a236a232156d8b9b18d1667.story': {'People': {'Casey Kasem',
#    'Danny Deraney',
#    'Jane Caffrey',
#    'Jean Kasem',
#    'Julie',
#    'Kerri Kasem',
#    'Mike Kasem',
#    'Scott Thompson',
#    'Shaggy'},
#   'Organizations': {'CNN',
#    'Gig Harbor',
#    'NBC',
#    'Scooby-Doo',
#    'St. Anthony Hospital',
#    'Washington court'},
#   'Locations': {'California', 'Santa Monica', 'western Washington'},
#   'Dates': {'2009'}},
#  '000994296459fb84cf26cf71a0c109c192758c11.story': {'People': {'Maddy Andrew',
#    'Mike',
#    'Paula Andrew',
#    'Stephen Hayes'},
#   'Organizations': {'North Yorkshire Police'},
#   'Locations': {'Scarborough', 'promenade'},
#   'Dates': set()},
#  '0009ca480b5c9d311cb43f852529e5e2a346fef5.story': {'People': {'Jennifer Thompson',
#    'Scott Mann'},
#   'Organizations': {'Dayton Daily News',
#    'Logan County Sheriff',
#    'Riverside middle school'},
#   'Locations': {'De Graff', 'Ohio'},
#   'Dates': set()},
#  '000beb8706bc2ad4c0c3040faf0ce54caa315454.story': {'People': {'Irvine Patnick',
#    'Lucy Osborne',
#    'Lynda',
#    'Matthew',
#    'Nick Clegg',
#    'Rosie Taylor',
#    'Sheffield Hallam',
#    'Suzanne'},
#   'Organizations': {'Hillsborough Independent Panel',
#    'Kingfield Synagogue',
#    'Liverpool',
#    'Maccabi sports',
#    'OBE',
#    'Sheffield Jewish Representative Council',
#    'youth organisation'},
#   'Locations': {'Buckingham Palace', 'Sheffield'},
#   'Dates': {'1980', '1987 to 1997', '31 December 2012', 'December 30'}},
#  '000c5ee0134182945f21c67d4e8af59259cf77a2.story': {'People': {'Barry Watson',
#    'Beverly Mitchell',
#    'Catherine Hicks',
#    'David Gallagher',
#    "Donna D'Errico",
#    'Eric Camden',
#    'Faye Grant',
#    'Ilene',
#    'Jessica Biel',
#    'Kate',
#    'Keri Russell',
#    'Mackenzie Rosman',
#    'Stephen Collins'},
#   'Organizations': {'7th Heaven',
#    'Baywatch',
#    'Boston radio station',
#    'LAPD',
#    'MailOnline',
#    'NYPD',
#    'Playboy',
#    'Screen Actors Guild',
#    'Special Victims Squad',
#    'TMZ',
#    'Ted 2',
#    "The Babysitter's Seduction"},
#   'Locations': {'California', 'Los Angeles', 'New York', 'Tarzana'},
#   'Dates': {'1990s', '2007', '2012'}},
#  '000cd1ee0098c4d510a03ddc97d11764448ebac2.story': {'People': {'Kamal Prasad Kharel',
#    'Maheshwor Dhakal'},
#   'Organizations': {'CNN',
#    'Department of National Parks',
#    'Wildlife Conservation'},
#   'Locations': {'Baitadi',
#    'Himalayas',
#    'India',
#    'Kathmandu',
#    'Nepal',
#    'Uttarkhand'},
#   'Dates': set()},
#  '000cefd88b6f79d28c1fb220d5a3eed19514a462.story': {'People': {'Daily Mail Reporter',
#    'Michelle Elliott'},
#   'Organizations': {'Fragile Hearts', 'Leeds General', 'NHS', 'NHS England'},
#   'Locations': set(),
#   'Dates': {'19:55 EST', '21 June 2013', 'April 2009', 'April 2013'}},
#  '000e009f6b1d954d827c9a550f3f24a5474ee82b.story': {'People': {'Barack Obama',
#    'Barbara Starr',
#    'Kyle White'},
#   'Organizations': {'Army',
#    'Army Special Forces',
#    'CNN',
#    'Chosen Company',
#    'Congressional Medal of Honor Society',
#    'NPR',
#    'National Public Radio',
#    'Stars and Stripes'},
#   'Locations': {'Afghanistan',
#    'America',
#    'Charlotte',
#    'Iraq',
#    'North Carolina',
#    'White House'},
#   'Dates': {'2007', '9/11/2001', 'February 10', 'November 9'}},
#  '000e7f26e4dda517050bc09ee8d9a08a3b2334b7.story': {'People': {'Louise Eccles',
#    'Melissa Reid',
#    'Michaella McCollum Connolly',
#    'Rebecca Hughes',
#    'William Reid'},
#   'Organizations': {'Colombian gang', 'Colombian mafia', 'Lenzie'},
#   'Locations': {'Dirandro police station',
#    'Dungannon',
#    'Glasgow',
#    'Ibiza',
#    'Lima',
#    'Northern Ireland',
#    'Peru',
#    'Peruvian',
#    'San Antonio Bay'},
#   'Dates': {'20 August 2013', '8/19/2013', 'August 6'}},
#  '000f9a3513a610ff46580007e9ef7e9dd0bc9fef.story': {'People': {'Mark David',
#    'Mary Buehrle',
#    'Pamela Hobley',
#    'Patricia Spencer'},
#   'Organizations': {"48 Hours' Crimesider",
#    'Missing Persons of America',
#    'National Center For Missing Children',
#    'Oscoda High School',
#    'Oscoda Township Police'},
#   'Locations': {'Michigan', 'Oscoda', 'River Road', 'Wilber Township'},
#   'Dates': {'10/31/1969', '2010'}},
#  '000fdddcbfce58b56605f99e81c22c9b86ea4773.story': {'People': {'Jill Reilly',
#    'Kathleen Castro',
#    'Kendrick Doidge',
#    'Mike Burke'},
#   'Organizations': {"Escambia County Sheriff's Office",
#    'Pensacola News Journal',
#    'Sacred Heart Hospital',
#    'West Florida Hospital'},
#   'Locations': {'Escambia County Jail', 'Florida', 'United States'},
#   'Dates': set()},
#  '0012256d996ac32c25dd1723785e567b3c063cab.story': {'People': {'Amanda Knox',
#    'Ashley',
#    'Carlo Dalla Vedova',
#    'Chris',
#    'Colin Sutherland',
#    'Delaney',
#    'Edda Mellas',
#    'James Terrano',
#    'John Kerry',
#    'Markus Wiget',
#    'Meredith Kercher',
#    'Raffaele Sollecito',
#    'Rudy Guede'},
#   'Organizations': {'University of Washington', 'West Seattle Herald'},
#   'Locations': {'Highline',
#    'Italian prison',
#    'Italy',
#    'New York',
#    'Rome',
#    'Seattle',
#    'Washington'},
#   'Dates': {'2007', '2011', '2013'}},
#  '0012c075cf01cbdc30895f7a1568cf556225c0c3.story': {'People': {'Cheryl',
#    'David Gingras',
#    'Nik Richie',
#    'Sarah Jones',
#    'William Bertelsman'},
#   'Organizations': {'ABC',
#    'CDA',
#    'Cincinnati Bengals',
#    'Communications Decency Act',
#    'Daily Mail Reporter',
#    'Dixie Heights High School',
#    'U.S. Circuit Court of Appeals'},
#   'Locations': {'Covington', 'Edgewood', 'Kentucky'},
#   'Dates': {'1996', '2009', 'December 31', 'June 27', 'October 1'}},
#  '00139ad128fc573dac7dfe4ce4921a07a408be60.story': {'People': {'Fairfax',
#    'Ibrahim Abu Mohamed',
#    'Jamal Daoud',
#    'Katrina Dawson',
#    'Mamdouh Habib',
#    'Man Haron Monis',
#    'Tori Johnson'},
#   'Organizations': {'Daily Telegraph',
#    'Eight Selborne',
#    'Hezbollah Australia',
#    'Muslims',
#    'News Corp',
#    'SPG',
#    'Shia',
#    'State Protection Group',
#    'Sunni',
#    'Sydney Muslim community',
#    'Telegraph',
#    'The Bomb Squad'},
#   'Locations': {'Auburn',
#    'Australia',
#    'CBD',
#    'Granville',
#    'Guantánamo Bay',
#    'Lindt café',
#    'Martin Place',
#    'Melbourne',
#    'Nabi Akram Islamic Centre',
#    'Pakistan',
#    'Sydney'},
#   'Dates': {'12/16/2023', '2007', '2009', 'December 16', 'September 11'}},
#  '0013a4baaf65a56c857088f2e236bfbc080c88dc.story': {'People': {'Gregory Carro',
#    'Helen Collis',
#    'Helen Pow',
#    'Jesus',
#    'Jill Reilly',
#    'Karen Rosenbaum',
#    'Kevin Krim',
#    'Leo Krim',
#    'Lucia',
#    'Marina Krim',
#    'Nessie',
#    'Valerie Van Leer-Greenberg',
#    'Yoselyn Ortega'},
#   'Organizations': {'CNBC',
#    'Lulu & Leo Fund',
#    'NY Daily News',
#    'State Supreme Court',
#    'news service'},
#   'Locations': {'California',
#    'Dominican Republic',
#    'Los Angeles',
#    'New York',
#    'Tarzana'},
#   'Dates': {'8/13/2013', 'October 25'}},
#  '001553918ab13ec4d55b7adf9175ba021fc1f7f8.story': {'People': {'Alma Silva Ramirez',
#    'Isaac Ramirez',
#    'Jesse Ramirez',
#    'Joshua John',
#    'Joshua Lorenzo Ramirez',
#    'Joshua Ramirez',
#    'Krystal Ramirez',
#    'Saul Tarango',
#    'Steve Robson',
#    'Teresa Ramirez'},
#   'Organizations': {'Amarillo Globe-News',
#    'Hereford ISD',
#    'Hereford Independent Schools District',
#    'KAMR-TV',
#    'Plainview High School'},
#   'Locations': {'Houston', 'Texas'},
#   'Dates': {'1998',
#    '3/22/2013',
#    'Feb.10',
#    'March 10',
#    'March 12',
#    'March 17',
#    'March 8'}},
#  '00169039da88af38387c7da51d021868fcb6f26c.story': {'People': {'Alison Quanbrough',
#    'Edward Copland',
#    'Sam Webb',
#    'Steven Duffy'},
#   'Organizations': {'Crown Prosecution'},
#   'Locations': {'Blackpool', 'Lancashire', 'Lytham Road'},
#   'Dates': {'2023-10-29 00:00:00'}},
#  '0016a36506199baae4cae50cd0758e45dddf87e7.story': {'People': {'Dave Fairbairn',
#    'Geoff Knights',
#    'Gillian Taylforth',
#    'Kathy Beale'},
#   'Organizations': {'EastEnders',
#    'MailOnline',
#    'North & East Hertfordshire Magistrates Court'},
#   'Locations': {'Bristol Crown Court',
#    'Cambridgeshire',
#    'Fore Street',
#    'Hertfordshire',
#    'UK'},
#   'Dates': {'2/7/2023', '2003', '2009', '2012', 'February 23'}},
#  '0016bfe904685ce40f094b07c294c2065dd3a194.story': {'People': {'Jessica Jerreat'},
#   'Organizations': {'Atlanta Journal Constitution',
#    'Crime Scene Investigation',
#    'Grady Hospital',
#    'Marcus Trauma Center',
#    'Therrell'},
#   'Locations': {'Atlanta High School',
#    'Southwest Atlanta',
#    'Therrell High School'},
#   'Dates': set()},
#  '0018963c6bfd060dbbbd6633a5655712d90643fb.story': {'People': {'Camilla Parker Bowles',
#    'Duchess of Kent',
#    'Duke',
#    'Duke of Edinburgh',
#    'Hugh van Cutsem',
#    'James Everett',
#    'Karen Melhado',
#    'Kate',
#    'Neville Warnes',
#    'Prince Charles',
#    'Queen',
#    'Rebecca English',
#    'Sandringham',
#    'William'},
#   'Organizations': {'Anmer Mere Yacht Club',
#    'Lynn and West Norfolk Borough Council',
#    'RAF',
#    'Royal'},
#   'Locations': {'Anglesey',
#    'Anmer Hall',
#    'Buckingham Palace',
#    'Duchess of Cambridge',
#    'Duchess of Cornwall',
#    'Duke',
#    'Grade II',
#    'Kensington Palace',
#    'Norfolk mansion',
#    'Nottingham Cottage',
#    'Sandringham Estate',
#    'St Mary the Virgin Church',
#    'West London',
#    'York'},
#   'Dates': {'10 January 2013',
#    '11 January 2013',
#    '1802',
#    '1972',
#    '1990',
#    '2001',
#    '2017',
#    'December 10',
#    'March 11'}},
#  '00197f390e3dd2ce02eabb5fd44bb40b89b64389.story': {'People': {"Denise 'Miki' Spies",
#    'Lydia Warren',
#    'Matt Lauer',
#    'Miki Spies',
#    'Sydney Spies'},
#   'Organizations': {'American Horror House',
#    'Durango High School',
#    'The Durango Herald',
#    'Westwood newspaper'},
#   'Locations': {'Colorado', 'Denver', 'Durango', 'Louisiana'},
#   'Dates': {'6/24/2023', 'Halloween'}},
#  '0019f3f79be4536756ac180d154bf67294d0c9b6.story': {'People': {'Graham Bevan',
#    'John Potter',
#    'Mitigating Arshad Mahmood',
#    'Ms Qureshi',
#    'Shamalia Qureshi'},
#   'Organizations': {'Bradford Crown Court', 'Daily Mail', 'Sony Ericsson'},
#   'Locations': {'Haworth', 'West Yorks'},
#   'Dates': {'1 December 2011', '2007', '3/12/2013'}},
#  '001a8b20279cb0b829cdb4fa8cd6997949c33f09.story': {'People': {'Artyon Pogosyan',
#    'Chris Parsons',
#    'Jill Reilly',
#    'Maxim Prisyjnikov',
#    'Oksana Makar',
#    'Simon Tomlinson',
#    'Tetyana Surovitska',
#    'Yanukovych',
#    'Yevgeniy Krasnoshek'},
#   'Organizations': {'Femen',
#    'Gazeta.ua',
#    'Hurriyet Daily News',
#    'Kyiv Post',
#    'Mykolayiv'},
#   'Locations': {'Donetsk', 'Kyiv', 'Ukraine'},
#   'Dates': {'3/9/2023', 'March 13'}},
#  '001b4673dbb3437282cd2ea58d9eca471e25780f.story': {'People': {'Andrey Lipatov',
#    'Anzhelina Vorontsova',
#    'Galina Stepanenko',
#    'Gennady Yanin',
#    'Nikolai Tsiskaridze',
#    'Pavel Dmitrichenko',
#    'Sergei Filin',
#    'Yuri Zarutsky'},
#   'Organizations': {'Bolshoi Ballet',
#    'CNN.com',
#    'Ivan the Terrible',
#    'Moscow Police',
#    'RIA Novosti news',
#    'Swan Lake'},
#   'Locations': {'Bolshoi Theatre'},
#   'Dates': {'3/1/2011', 'January 17'}},
#  '001b6dccba3ab0efb4296e04669bac42f5bee886.story': {'People': {"A'zhari Jones",
#    "A'zhiah",
#    'Adrienne Spates',
#    'Jacob Spates',
#    'Jill Reilly',
#    'Joshua',
#    'Max Langham'},
#   'Organizations': {'Department of Child Services', 'TODAY'},
#   'Locations': {'Le Bonheur Children’s Hospital',
#    'Memphis',
#    'Regional Medical Center',
#    'Virginia'},
#   'Dates': {'10/22/2013', '2011', 'April 2012', 'January 24'}},
#  '001b8ecda7b31fff8ab04a99a0455336477f09a1.story': {'People': {'Briton',
#    'Clare',
#    'Florence Hegoburu',
#    'Fraser',
#    'Helga Wauters',
#    'Iris',
#    'Isaac',
#    'Xynthia Hawke',
#    'Yannick Balthazar'},
#   'Organizations': {'Haygrove School', 'University of London Institute'},
#   'Locations': {'France',
#    'French Pyrenees',
#    'Orthez',
#    'Paris',
#    'Pau',
#    'Petherton',
#    'Somerset',
#    'UK',
#    'Ustaritz'},
#   'Dates': {'9/26/2023', 'September 30'}},
#  '001c9b4f4f1f431b85bae0abaadf4e7666064f35.story': {'People': {'Dianne Staniforth',
#    'Julie Baird',
#    'Paul',
#    'Pc Michelle Witham'},
#   'Organizations': {'Department of Work and Pensions', 'Samaritans'},
#   'Locations': {'Chesterfield',
#    'Derbyshire',
#    'Pinderfields Hospital',
#    'Sheffield Hospital',
#    'Wakefield',
#    'West Yorkshire'},
#   'Dates': {'April 22', 'April 28', 'October 2012'}},
#  '001db2e0e30e54bc5effda388ffb51425d018caf.story': {'People': {'Brian Blackwood',
#    'Buddha',
#    'Htut Ko Ko Lwin',
#    'Myat Nandar',
#    'Phil Robertson',
#    'Philip Blackwood',
#    'Tun Thurein',
#    'Ye Lwin'},
#   'Organizations': {'Fairfax Media',
#    'Human Rights Watch',
#    'New Zealander',
#    'Religious Department',
#    'VGastro Bar'},
#   'Locations': {'Myanmar', 'New Zealand', 'VGastro bar', 'Yangon'},
#   'Dates': {'2011'}},
#  '001dc91a62bad5263259a1d664c821cb1e700f27.story': {'People': {'David Baldwin',
#    'James Jones Jr',
#    'Jonathon Myles',
#    'Jordan Baker',
#    'Kaylnn Ruthenberg'},
#   'Organizations': {'ABC News',
#    'Brown Middle School',
#    'Clark Atlanta University',
#    'Craigslist',
#    'Fickett Elementary School',
#    'HBCU Rising Cares Mentoring',
#    'Marietta Police'},
#   'Locations': {'Atlanta', 'Central Florida', 'Daytona Beach'},
#   'Dates': set()},
#  '001e8bda2f7ab73bf81314c1639a97dae2751703.story': {'People': {'Angela Corey',
#    'Craig Sonner',
#    'Cristian Fernandez',
#    'David',
#    'Dee Dee',
#    'Dennis Baxley',
#    'George Zimmerman',
#    'Hal Uhrig',
#    'Joran Van Der Sloot',
#    'Norman Wolfinger',
#    'Sean Hannity',
#    'Sunny Hostin',
#    'Trayvon Martin'},
#   'Organizations': {'4th Judicial Circuit',
#    'CNN',
#    'Fox News',
#    'Sanford Police',
#    'Target'},
#   'Locations': {'Duval County jail',
#    'Jacksonville',
#    'New York',
#    'Northeast Florida',
#    'Seminole County Courthouse'},
#   'Dates': {'4/10/2023', 'February 26'}},
#  '001f7a255ce06e0bc3a8cffb94fc0019ba0f2f34.story': {'People': {'Diva Poss',
#    'Italvino',
#    'Rafael Max'},
#   'Organizations': {'Express UK', 'The Huffington Post'},
#   'Locations': set(),
#   'Dates': {'1948'}},
#  '001fb37cf8a91dd358548d409d1ea09f4120ab6f.story': {'People': {'Andrew Gilligan',
#    'Boris Johnson',
#    'Brian Holt',
#    'Dave',
#    'Francis Golding',
#    'James',
#    'Michelle Baharier',
#    'Richard Muzira',
#    'Roger William De Klerk',
#    'Roger de Klerk',
#    'Sam Webb',
#    'Venera Minakhmetova',
#    'Vigil'},
#   'Organizations': {'BBC London 94.9',
#    'Bank of America',
#    'City Hall',
#    'CoolTan Arts',
#    'Evening Standard',
#    'Mental Health and Disability',
#    'Metropolitan Police Service',
#    'The Parliamentary Advisory Council for Transport Safety'},
#   'Locations': {'Aldgate',
#    'Camberwell',
#    'Camberwell Road',
#    'Camden',
#    'Croydon',
#    'Cycle Superhighway 2',
#    'Dulwich',
#    'Forest Hill',
#    'Holborn',
#    'London',
#    'Mile End Road',
#    "St John's Wood",
#    'Whitechapel'},
#   'Dates': {'11/19/2013', '2011', '2012', 'November 12th', 'November 5th'}},
#  '0021fe8d65bd0d6d76d5fefba2ac02f0c48a43f4.story': {'People': {'Anne Donnelly',
#    'Anthony Moschetto',
#    'Christi Paul',
#    'James Chmela',
#    'James Kalamaras',
#    'Randy Zelin'},
#   'Organizations': {'CNN', 'Nassau County District Court', 'New Day', 'WCBS'},
#   'Locations': {'Long Island'},
#   'Dates': set()},
#  '0022a8a7afe47ac14e7ed51c38f629c866661e38.story': {'People': {'Chris Gleeson',
#    'Christine Lee',
#    'John Lowe',
#    'Lucy Lee',
#    'Mark Dennis QC',
#    'Rafferty',
#    'Stacey Banner',
#    'Susanna Wilson'},
#   'Organizations': {'Guildford Crown Court'},
#   'Locations': {'Farnham', 'Surrey', 'Tilford'},
#   'Dates': {'2/23/2023', '2013'}},
#  '0022b77434a498d0bf38836caa3ec8c071f624f6.story': {'People': {'Betsy Randolph',
#    'Bruce Peoples',
#    'Debbie McManaman',
#    'Jimmy Allen Williams',
#    'Kim Carmichael',
#    'Leah Gail Johnson',
#    'Thomas Michael Rios',
#    'Wayne'},
#   'Organizations': {'Camaro',
#    'Chevrolet',
#    "Custer County Sheriff's Department",
#    'Daily Mail',
#    'KFOR',
#    'KWEY',
#    'Newsnine.com',
#    'Oklahoma Bureau of Investigation',
#    'Oklahoma Highway Patrol'},
#   'Locations': {'Beckham County',
#    'Custer County',
#    'Elk City',
#    'Foss Lake',
#    'Highway Patrolmen',
#    'Oklahoma',
#    'Sayre',
#    'Washita County'},
#   'Dates': {'18 September 2013',
#    '1950s',
#    '1960s',
#    '1969',
#    '1970',
#    '2003',
#    '9/17/2013',
#    'November 10 1970',
#    'November 20'}},
#  '002360f910e8b59949ff31b49af0a7b8126593d3.story': {'People': {'Esme Smith',
#    'Hugo Gye',
#    'Jon Savell',
#    'Mark Smith',
#    'Sian'},
#   'Organizations': {'All Hallows Catholic School',
#    'CCTV',
#    'Facebook',
#    'Gulf War',
#    'Joint Warfare Centre',
#    'Metropolitan Police',
#    'Nato',
#    'Surrey\xa0Police',
#    'Twitter'},
#   'Locations': {'Afghanistan',
#    'Aldershot railway station',
#    'Charing Cross',
#    'Farnham',
#    'London',
#    'Northern Ireland',
#    'Surrey',
#    'Waterloo',
#    'Woking'},
#   'Dates': {'24 September 2013',
#    '9/23/2013',
#    'September 12',
#    'September 19',
#    'September 20',
#    'September 23'}},
#  '00238f16261b335618b065b5a4e5433de3c14615.story': {'People': {'Abraham Cumberbatch',
#    'Abraham Parry',
#    'Ann',
#    'Benedict Cumberbatch',
#    'Bussa',
#    'Joshua',
#    'Solomon Northup',
#    'Steven Tempro',
#    'Timothy Carlton',
#    'Tracie Bennett',
#    'Wanda Ventham',
#    'William Ford',
#    'William Pitt'},
#   'Organizations': {'12 Years A Slave',
#    'Amazing Grace',
#    'Ejiofor Property',
#    'MailOnline',
#    'Taunton School'},
#   'Locations': {'Barbados',
#    'Britain',
#    'Cleland',
#    'Cleland Plantation',
#    'Devon',
#    'Fairwater House',
#    'Saint Andrew',
#    'St Nicholas Abbey',
#    "St Peter's Parish Church",
#    'UK'},
#   'Dates': {'1750',
#    '1816',
#    '1820',
#    '1830s',
#    '1838',
#    '18th and 19th centuries',
#    '1985',
#    '2006',
#    '2012',
#    '2013',
#    'February 22',
#    'late 17th century'}},
#  '00a3121ae106ce18379649be9d61faaf9b885ea7.story': {'People': {'Barack Obama',
#    'Mitt Romney',
#    'Newt Gingrich',
#    'Rick Perry',
#    'Rick Santorum',
#    'Ron Paul',
#    'Sarah Palin'},
#   'Organizations': {'Bain Capital',
#    'Fox News',
#    'GOP',
#    'Republican',
#    'White House'},
#   'Locations': {'Art Trails Gallery in Florence',
#    'Columbia',
#    'Iowa',
#    'Myrtle Beach',
#    'New Hampshire',
#    'South Carolina'},
#   'Dates': {'2008'}},
#  '00a6c0823ba92e5a055d90133e8b66fa9028c2d7.story': {'People': {'Barack Obama',
#    'Chuck Hagel',
#    'Frank-Walter Steinmeier',
#    'Gennady Kernes',
#    'Kernes',
#    'Kiev',
#    'Michael Bociurkiw',
#    'Obama',
#    'Putin',
#    'Sergei Shoigu',
#    'Shoigu',
#    'Stella Khorosheva',
#    'Vladimir Putin',
#    'Vyacheslav Ponomarev'},
#   'Organizations': {'CNN',
#    'Commerce',
#    'Defense',
#    'Defense Ministry',
#    'Kiev',
#    'NATO',
#    'OSCE',
#    'Pengaton',
#    'Pentagon',
#    'Ponomarev',
#    'State',
#    'The European Union',
#    'The White House',
#    "Ukraine's Defense Ministry",
#    'the Council of the European Union',
#    'the Defense Ministry',
#    'the Organization for Security and Co-operation'},
#   'Locations': {'Eastern Europe',
#    'Europe',
#    'Russian',
#    'U.S.',
#    'Ukraine',
#    'eastern Ukrainian city'},
#   'Dates': set()},
#  '00a7132b9c9a646852ac4a606acb71e3a6acb8c6.story': {'People': {'Customers'},
#   'Organizations': {'CNN', 'Sony'},
#   'Locations': {'Japan', 'TOKYO'},
#   'Dates': {'2007', '2008', 'December 31', 'March 31'}},
#  '00b3cebdfa5caccbddb4c701689e2dfddd89a3d4.story': {'People': {'Andy Williams',
#    'St. Nick'},
#   'Organizations': {'Topdeck Travel'},
#   'Locations': {'Africa',
#    'Anatolia',
#    'Angkor',
#    'Arusha National Park',
#    'Atlantic',
#    'Austrian village of Kirchdorf',
#    'Austrian village of Kirchhoff',
#    "Beijing's Forbidden City",
#    'Berber',
#    'Buenos Aires',
#    'California',
#    'Cambodia',
#    'Cancún',
#    'Cappadocia',
#    'Chichén Itzá',
#    'Chile',
#    'Essaouira',
#    'Fez',
#    'French',
#    'Gallipoli',
#    'Harbin',
#    'Ice and Snow World',
#    'Innsbruck',
#    'Istanbul',
#    'Kilimanjaro',
#    'Kirchdorf',
#    'Laos',
#    'Las Vegas',
#    'Luang Prabang',
#    'Marrakech',
#    'Mayan',
#    'Morocco',
#    'Patagonia',
#    'Playa del Carme',
#    'Roman',
#    'Sahara',
#    'Salzburg',
#    "San Francisco's Coit Tower",
#    'Santiago',
#    'Tulúm',
#    'Turkey',
#    'Uxmal',
#    'Volubilis',
#    "Xi'an",
#    'Yosemite',
#    'busy souk',
#    'hacienda',
#    'mangroves',
#    'museums of Mérida',
#    'northeast China',
#    'rainforest',
#    'the Asian portion of modern-day Turkey',
#    'the Blue Mosquem',
#    'the Grand Canyon',
#    'the Great Wall',
#    'the Mekong River',
#    'the North Pole',
#    'the Yucatán Peninsula'},
#   'Dates': {'2013',
#    'December 18',
#    'December 19',
#    'December 21',
#    'December 22',
#    'December 23',
#    'December 28',
#    'December 29',
#    'December 30',
#    'December 31',
#    'January 2',
#    'January 3',
#    'January 4',
#    'January 6'}},
#  '00bab59ff44f83281a07ff92439089c58c2f54bb.story': {'People': {'Anne Grace',
#    'Arlene Salac',
#    'Bryan Lanzello',
#    'Lois Farella',
#    'Ms Grace',
#    'Victoria Wellman'},
#   'Organizations': {'CBS',
#    'FAA',
#    'MailOnline',
#    'the Federal Aviation Administration'},
#   'Locations': {'John F Kennedy airport', 'Long Island', 'Valley Stream'},
#   'Dates': {'2012-09-11 00:00:00'}},
#  '00d48bf5089a093edf12ef5f3836780e97be6be0.story': {'People': {'Kentaro',
#    'Lucas Leiva',
#    'Mark Shearan',
#    'Neymars'},
#   'Organizations': {'Arsenal',
#    'Brazil',
#    'CNN',
#    'England',
#    'Liverpool',
#    'Metropolitan Police',
#    'SFA',
#    'Santos',
#    'Scottish FA',
#    'Scottish Football Association'},
#   'Locations': {'Brazil', 'Emirates Stadium', 'Europe', 'London', 'Scotland'},
#   'Dates': {'2014'}},
#  '00f2dcbaf64df265065f3ef314f5bbc17e6950ca.story': {'People': {'Edward Snowden',
#    'James Clapper'},
#   'Organizations': {'Anchory',
#    'Associated Press',
#    'Daily Mail Reporter',
#    'Journal',
#    'Maui',
#    'NSA',
#    'National Intelligence James Clapper',
#    'Reuters',
#    'Reuters Reporter and Associated Press',
#    'Surveillance',
#    'The Journal',
#    'court',
#    'the National Security Agency',
#    'the Wall Street Journal'},
#   'Locations': {'Maryland', 'U.S.'},
#   'Dates': {'08:34 EST', '15:18 EST', '21 August 2013'}},
#  '0189e00e90723bc2449a3522557b4edfa54ebf52.story': {'People': {'Sandra Zouzalova',
#    'businessmen',
#    'foreign diplomats'},
#   'Organizations': {"Prague's Jalta Hotel",
#    'a museum of communist-era history',
#    'state security agents',
#    'the Ministry of Defence'},
#   'Locations': {'Prague'},
#   'Dates': {'10:47 EST',
#    '13:07 EST',
#    '1989',
#    '1998',
#    '2 December 2013',
#    'between 1954 and 1958',
#    'the 1980s',
#    'the iron curtain came down'}},
#  '069f469ad0d105a36345ad93637b6c10771fb8f3.story': {'People': {'Andy',
#    'Andy Murray',
#    'Angelique Kerber',
#    'Dimitrov',
#    'Grigor Dimitrov',
#    'Kate',
#    'Katy Winter',
#    'Kim',
#    'Kim Sears',
#    'Maria',
#    'Maria Sharapova',
#    'Murray',
#    'Patrick Mouratoglou',
#    'Serena',
#    'Serena Williams',
#    'Sharapova',
#    'Williams',
#    'the Duchess of Cambridgem'},
#   'Organizations': {'Burberry',
#    'Goat',
#    'the All England Club',
#    'the Royal Box'},
#   'Locations': {'Highbury', 'Islington', 'North London', 'Sugarpova'},
#   'Dates': {'2004', '2012', '2013'}},
#  '09b9fda5fe70b96e95d9899f080dccb0e0dcd77a.story': {'People': {'Charlie Webster',
#    'Ched',
#    'Ched Evans',
#    'Hibernian',
#    'Jeffrey Farrugia',
#    'Jessica Ennis-Hill',
#    'Natasha Massey',
#    'Stephen Vaughan'},
#   'Organizations': {'HFC',
#    'Hartlepool United',
#    'Hibernians',
#    'Hibernians  Evans',
#    'Maltese Premier League club',
#    'Oldham Athletic',
#    'Scottish Championship',
#    'Sheffield United',
#    'Sky Sports News',
#    'Tranmere Rovers',
#    'Twitter'},
#   'Locations': {'Bramall Lane', 'Malta', 'Maltese', 'Paola', 'UK'},
#   'Dates': {'2011', '2012'}},
#  '0a031d23cc9696d34b418d6b8d46fb2be777db23.story': {'People': {'Theresa Lamagni'},
#   'Organizations': {'NHS', 'Public Health England\xa0(PHE)'},
#   'Locations': {'England'},
#   'Dates': {'1960s', '2015'}},
#  '0a045dcc5d3fddad8617a17db4fb36e490921b75.story': {'People': {'Adam Levy',
#    'Barack Obama',
#    'Ben Carson',
#    'Bill Hartzell',
#    'Bobby Jindal',
#    'Carly Fiorina',
#    'Chris Christie',
#    'Chuck Grassley',
#    'Donald Trump',
#    'Eric Rosenthal',
#    'Ernie Rudolph',
#    'Hillary Clinton',
#    'Jeb Bush',
#    'Joni Ernst',
#    'Marco Rubio',
#    'Michael Patomson',
#    'Mike Huckabee',
#    'Mitt Romney',
#    'Palin',
#    'Rand Paul',
#    'Rick Perry',
#    'Rick Santorum',
#    'Scott Walker',
#    'Steve King',
#    'Ted Cruz'},
#   'Organizations': {'Citizens United',
#    'Common Core',
#    'Congress',
#    'Fox News',
#    'Hewlett Packard',
#    'IRS',
#    'ISIS',
#    'Republican',
#    'State of the Union',
#    'White House'},
#   'Locations': {'Cedar Rapids',
#    'Council Bluffs',
#    'DES MOINES',
#    'Dallas County',
#    'Des Moines',
#    'Hawkeye State',
#    'Hoyt Sherman Place',
#    'Iowa',
#    'New Jersey',
#    'Pennsylvania',
#    'Texas',
#    'Washington',
#    'Wisconsin'},
#   'Dates': {'1877', '2008', '2011', '2012', '2016'}},
#  '0a0a007398ab02d4bd3c1ef9e034f567afa76b2c.story': {'People': {'Boris Johnson',
#    'Edmund King',
#    'Gordon Brown'},
#   'Organizations': {'AA', 'Daily Mail', 'European Commission'},
#   'Locations': {'London'},
#   'Dates': {'2001', 'the 1990s'}},
#  '0a0a1a0e94aac65f2b50815050dfaccf521dda35.story': {'People': {'David Coggon',
#    'Paul Elliott'},
#   'Organizations': {'Imperial College London',
#    'Mobile Telecommunications and Health Research Programme(MTHR Programme)',
#    'Norwegian Expert Committee',
#    'University of Oxford',
#    'World Health Organisation(WHO)'},
#   'Locations': {'UK'},
#   'Dates': {'2011', '2012'}},
#  '0a0a4c90d59df9e36ffec4ba306b4f20f3ba4acb.story': {'People': {'Carl Levin',
#    'Dean Obeidallah',
#    'Dianne Feinstein',
#    'John Krasinski',
#    'John McCain',
#    'Matt Damon',
#    'Osama bin Laden',
#    'Peter Bergen'},
#   'Organizations': {'Energy in Depth', 'Hollywood', 'Sony Pictures'},
#   'Locations': {'US'},
#   'Dates': set()},
#  '0a0d524f9f21f6132b91422e00b575080bb7c4a6.story': {'People': {'Karen Lorre',
#    'Nicole Daedone',
#    'Pooja Lakshmin',
#    'Rachel',
#    'Sarah Griffiths'},
#   'Organizations': {'Buddhist Tantric',
#    'Medical Daily',
#    'OneTaste',
#    'Playmate',
#    'Rutgers University'},
#   'Locations': {'San Francisco'},
#   'Dates': {'8 August 2013'}},
#  '0a167e1b287070c1ac577400309a55d499939d2c.story': {'People': {'David Cameron',
#    'Rafal Trzaskowski'},
#   'Organizations': {'BBC Newsnight', 'European Union(EU)'},
#   'Locations': {'Britain', 'Poland', 'UK'},
#   'Dates': set()},
#  '0a1ef61e85845fc03a2aad06aabad8d34e0b36ad.story': {'People': {'Barack Obama',
#    'Enrique Pena Nieto',
#    'Harry Reid',
#    'Jay Carney',
#    'Joe Biden',
#    'Mitch McConnell',
#    'Nancy Pelosi',
#    'Stephen Harper'},
#   'Organizations': {'Congress',
#    'Democratic',
#    'Keystone XL',
#    'Pacific nations',
#    'Republican',
#    'Senate',
#    'State Department',
#    'Trans-Pacific Partnership',
#    'White House'},
#   'Locations': {'Alberta',
#    'Canada',
#    'Mexico',
#    'Toluca',
#    'United States',
#    'the Gulf of Mexico'},
#   'Dates': set()},
#  '0a23ba95558bc16e21815b6d1297b60c0e78caaa.story': {'People': set(),
#   'Organizations': {'CNN Student News'},
#   'Locations': {'France', 'Indonesia'},
#   'Dates': {'2015-01-13 00:00:00'}},
#  '0a3bcbacfb0040800aba71a470c0194d0d7c5a62.story': {'People': {'Adam Levine',
#    'Anders Fogh Rasmussen',
#    'Andrew Hoehn',
#    'Chris Lawrence',
#    'Madeleine Albright',
#    'Mikhail Saakashvili',
#    'Obama',
#    'Sarah Harting'},
#   'Organizations': {'European Union',
#    'NATO',
#    'NATO Ivo Daalder',
#    'RAND Corporation',
#    'Senate',
#    'U.S. Congress'},
#   'Locations': {'Afghanistan',
#    'Europe',
#    'Georgia',
#    'Lisbon',
#    'Moscow',
#    'Portugal',
#    'Russia',
#    'Saakashvili',
#    'United States'},
#   'Dates': {'2011', '2014', '21st century'}},
#  '0a459eb9164b45589795af3ad7c7f6dd22685af0.story': {'People': {'Kevin McCloud',
#    'Suzanna'},
#   'Organizations': {'Channel 4\xa0programme',
#    'Grand Designs',
#    'Happiness Architecture Beauty',
#    'Times'},
#   'Locations': {'Britain', 'Burton', 'Europe', 'Swindon', 'UK'},
#   'Dates': {'1999'}},
#  '0a471293143e542e3f3ff00265bcadfbc68bda25.story': {'People': {'Alan Grayson',
#    'Anthony Cordesman',
#    'Barack Obama',
#    'Bashar al-Assad',
#    'Buck McKeon',
#    'Charlie Rose',
#    'Chuck Hagel',
#    'Denis McDonough',
#    'Ed Husain',
#    'George Tenet',
#    'John Kerry',
#    'William Polk'},
#   'Organizations': {'Assad regime',
#    'Bashaar al-Nasr',
#    'Britain',
#    'CBS',
#    'CIA',
#    'CSIS',
#    'Congress',
#    'Council on Foreign Relations',
#    'Defense',
#    'France',
#    'NATO',
#    'PBS',
#    'Russia',
#    'Syrian Coalition',
#    'Syrian Islamic Liberation Front',
#    'U.S.',
#    'U.S. Defense Department',
#    'U.S. State Department',
#    'United Nations(U.N.)',
#    'White House',
#    'al Qaeda',
#    'al-Nusra Front',
#    'the U.N. Independent International Commission of Inquiry for Syria'},
#   'Locations': {'Aleppo', 'Damascus suburb', 'Iraq'},
#   'Dates': {'2023-08-21 00:00:00'}},
#  '0a4a9488b5e913b1de866446d53073d113688768.story': {'People': {'Sue Lamb'},
#   'Organizations': {'ANZ', 'Daily Mail', 'Gold Coast Bulletin'},
#   'Locations': {'Australia', 'Gold Coast', 'Labrador', 'New Zealand'},
#   'Dates': {'2012'}},
#  '0a5c5a5f92c35ec03cd42feee53474d4164cbf33.story': {'People': {'Junko Ogura',
#    'Keith Henry',
#    'Shinzo Abe',
#    'Yoshihide Suga'},
#   'Organizations': {'Fukui District Court',
#    'Kansai Electric Power Company',
#    'Nuclear Regulation Authority',
#    'Sendai nuclear power plant'},
#   'Locations': {'Fukui Prefecture',
#    'Japan',
#    'Kagoshima Prefecture',
#    'Takahama',
#    'Tokyo'},
#   'Dates': {'2011'}},
#  '0a60266f622680ec18cc85219f9f7c76c4e10205.story': {'People': {'Andrew Montford',
#    'Benny Peiser',
#    'Ed Miliband',
#    'Henderson',
#    'John Shade',
#    'Lennart Bengtsson',
#    'Nigel Lawson'},
#   'Organizations': {'Global Warming Policy Foundation(GWPF)',
#    'Labour',
#    'Tory',
#    'US',
#    'University of Reading'},
#   'Locations': set(),
#   'Dates': {'2009/11/1', 'late 20th Century'}},
#  '0a60d5c98e767514e6431e2b61a900ccba178741.story': {'People': set(),
#   'Organizations': {'Daily Mail',
#    'New York City Department of Building',
#    'PIX 11 News',
#    'PS Marcato',
#    'PS Marcato Elevator Company',
#    'Queens',
#    'the New York Times'},
#   'Locations': {'West End', 'West End Avenue', 'the Long Island City'},
#   'Dates': {'1903', 'April 2014'}},
#  '0a61cc5c304b3d78070eea0d2686da69d56552f0.story': {'People': {'David Cameron',
#    'Iain Duncan Smith',
#    'James Chapman'},
#   'Organizations': {'Cabinet', 'EU', 'Labour', 'Liberal Democrat', 'Tory'},
#   'Locations': {'Britain', 'Madrid', 'UK'},
#   'Dates': {'1997', '2010', '2011/7/1'}},
#  '0a6e74e3116ca8246fa2d09929b59746973721f2.story': {'People': {'Brooke Anderson',
#    'Bull Connor',
#    'Doug Gross',
#    'Joe Arpaio',
#    'Paco Fabian',
#    'Phil Brown'},
#   'Organizations': {'FBI',
#    'Fox Reality Channel',
#    'Maricopa Co.',
#    'U.S. Justice Department'},
#   'Locations': {'Alabama',
#    'Arizona',
#    'California',
#    'HOLLYWOOD',
#    'Maricopa County',
#    'Phoenix',
#    'U.S.'},
#   'Dates': {'1960s'}},
#  '0a75c4f2a8a1468afbc2f2b1591d134c3cea30ec.story': {'People': {'Sylwester Wardega'},
#   'Organizations': {'YouTube'},
#   'Locations': {'Poland', 'Warsaw'},
#   'Dates': set()},
#  '0a7d822a4d9f7269255b194d01a3503e7e207c7f.story': {'People': {'David Cameron',
#    'Duke of Cambridge',
#    'Ed Balls',
#    'George Osborne',
#    'Liz Pearce',
#    'Prince William'},
#   'Organizations': {'Bank of England',
#    'British Business Bank',
#    'British Property Federation(BPF)',
#    'British Retail Consortium',
#    'CBI',
#    'Federation of Small Businesses',
#    'Labour',
#    'NHS',
#    'RAF Valley',
#    'manufacturers’ organisation EEF'},
#   'Locations': {'Anglesey', 'Birmingham', 'Britain', 'UK'},
#   'Dates': {'1601', '2011', '2012', 'Tudor\xa0times'}},
#  '0a80d772e87c235cb633a19107483e345d6ef46a.story': {'People': {'Cora Thiel',
#    'Oliver Ullrich'},
#   'Organizations': {'European Esrange Space Center',
#    'ISS',
#    'International Space Station',
#    'Plos One',
#    'University of Zurich'},
#   'Locations': {'Esrange in Kiruna', 'Kiruna', 'Sweden', 'northern Sweden'},
#   'Dates': set()},
#  '0a8201ae18c7db380e0d838e19ab73a16e82102f.story': {'People': {'Clare Pritchard'},
#   'Organizations': {'Hyndburn Council', 'PlaceFirst'},
#   'Locations': {'Accrington',
#    'Burnley',
#    'Lancashire',
#    'London',
#    'UK',
#    'Woodnook'},
#   'Dates': {'1811',
#    '1900',
#    '1911',
#    '2010',
#    '2014',
#    '21st century',
#    'mid 18th century'}},
#  '0a842d14099d3868d36adfdb269df65d14aa6c47.story': {'People': {'Adam Schiff',
#    'Barack Obama',
#    'Barbara Starr',
#    'Bowe Bergdahl',
#    'Buck McKeon',
#    'Caitlin Hayden',
#    'Carl Levin',
#    'Catherine Shoichet',
#    'Chuck Hagel',
#    'Dana Bash',
#    'Deirdre Walsh',
#    'Ed Payne',
#    'Elise Labott',
#    'Erin Burnett',
#    'Jeff Sessions',
#    'Jim Sciutto',
#    'Joe Manchin',
#    'John Boehner',
#    'John Kerry',
#    'John Kirby',
#    'Josh Earnest',
#    'Kevin Liptak',
#    'Osama bin Laden',
#    'Paul Steinhauser',
#    'Qadir Sediqi',
#    'Richard Durbin',
#    'Steve Warren',
#    'Virginia Nicolaidis'},
#   'Organizations': {'25th Infantry Division',
#    '4th Brigade Combat Team',
#    '501st Infantry Regiment',
#    'Congress',
#    'Democratic',
#    'House Armed Services Committee',
#    'House Intelligence Committee',
#    'National Defense Authorization Act',
#    'National Security Council',
#    'New York Times',
#    'Pentagon Senate Armed Services Committee',
#    'Republican',
#    'San Antonio Military Medical Center',
#    'Senate',
#    'Taliban',
#    'White House',
#    'al Qaeda',
#    'the 1st Battalion'},
#   'Locations': {'Afghanistan',
#    'Germany',
#    'Guantanamo Bay',
#    'Pakistan',
#    'Qatar',
#    'Texas',
#    'Washington'},
#   'Dates': {'2009', '2011', '2023/5/31', 'June 30'}},
#  '0a847504dcde9cd4a476ffb4e5c831e3dfcb2d58.story': {'People': {'Adam',
#    'Carlos Bustamante',
#    'Dan Graur',
#    'Eran Elhaik',
#    'Eve'},
#   'Organizations': {'Arizona University',
#    'MailOnline',
#    'Stanford University',
#    'University of Houston',
#    'University of Sheffield'},
#   'Locations': {'Africa'},
#   'Dates': {'000 to 115', '200', '500', '9', 'between 50', 'the earth 209'}},
#  '0a8b54bdaf7822a0ed3f462db4c8941ad53663ab.story': {'People': {'Abdullah bin Nasser bin Khalifa Al Thani',
#    'David Gauke',
#    'Margaret Hodge',
#    'Prince Charles',
#    'Simon Mallinson'},
#   'Organizations': {'Amazon',
#    'Apple',
#    'Barclays and Sainsbury',
#    'Chelsea Barracks',
#    'Christian Candy’s CPC Group',
#    'Google',
#    'HM Revenue and Customs',
#    'HSBC',
#    'Harrods',
#    'Ministry of Defence',
#    'Olympic Village',
#    'Park Lane Hotel',
#    'Qatar Investment Authority(QIA)',
#    'Real Capital Analytics',
#    'Savoy Hotel',
#    'Starbucks'},
#   'Locations': {'Britain',
#    'Canary Wharf',
#    'Knightsbridge',
#    'London',
#    'Qatar',
#    'UK'},
#   'Dates': {'2007', '2010'}},
#  '0a9d326b859a477b6466525a9afbb0c15c3dd9d8.story': {'People': {'Mary Rakovich',
#    'Obama',
#    'Rick Santelli'},
#   'Organizations': {'CNBC', 'Chicago Mercantile Exchange', 'Tea Party'},
#   'Locations': {'Florida'},
#   'Dates': {'2009-02-01 00:00:00'}},
#  '0aa0562353120d93357dc00a05ff4d2bc0312715.story': {'People': {'Australian Prime Minister',
#    'Bush',
#    'Dalai Lama',
#    'Hu Jintao',
#    'Kevin Rudd',
#    'Rudd'},
#   'Organizations': {'CNN',
#    'Chinese government',
#    'Olympic games',
#    "Tibet's government",
#    'Tibetan Buddhists',
#    'White House',
#    'Xinhua news'},
#   'Locations': {'Australian Prime Minister',
#    'Beijing',
#    'China',
#    'India',
#    'New Delhi',
#    'Tibet'},
#   'Dates': set()},
#  '0aa1dd8b2267ee1f4629c54af6aecb418a2f088b.story': {'People': {'Bob Dole',
#    'Rick Santorum',
#    'Ted Piccone'},
#   'Organizations': {'Congress',
#    'International Criminal Court',
#    'Republican',
#    'Senate',
#    'The Daily Beast',
#    'United Nations'},
#   'Locations': {'Libya', 'United States'},
#   'Dates': {'1948', '1990', '21st century', 'December 10'}},
#  '0aa577e33ead7f859e537050c3276ea02cb94af0.story': {'People': {'Bashar al-Assad',
#    'Kofi Annan',
#    'Randa Slim'},
#   'Organizations': {'Iran',
#    'National Coordination Committee for Change',
#    'Russia',
#    'Syrian National Council',
#    'United Nations'},
#   'Locations': {'Aleppo',
#    'Bahrain',
#    'Damascus',
#    'Egypt',
#    'Iran',
#    'Iraq',
#    'Lebanon',
#    'Saudi Arabia',
#    'Syria',
#    'Turkey'},
#   'Dates': set()},
#  '0aabc9ecdaaff12f92c65edfdc15c7f344058248.story': {'People': {'Amy Bonomi',
#    'Anuradha Paranjape',
#    'Chris Brown',
#    'Jane Dimer',
#    'Mark Crawford',
#    'Rihanna'},
#   'Organizations': {'Group Health Cooperative',
#    "Journal of Women's Health",
#    'National Institutes of Health',
#    'Temple University School of Medicine',
#    'The Ohio State University'},
#   'Locations': {'Georgia', 'Roswell', 'Seattle', 'Washington'},
#   'Dates': {'2008', 'Grammys on February 8'}},
#  '0ab34ea3704178a08dc1223bb10826912c73bd19.story': {'People': {'Jeffrey Toobin',
#    'Obama',
#    'Sonia Sotomayor'},
#   'Organizations': {'Christian Brothers Services',
#    'Justice Department',
#    'Obama administration',
#    'Obamacare',
#    'Supreme Court',
#    'The Catholic Church'},
#   'Locations': {'Colorado', 'Denver', 'Utah'},
#   'Dates': {'2012'}},
#  '0abbbc34252feacc63d3b0b5c051c5f1b7b967fe.story': {'People': {'Elrey "Bud" Runion',
#    'June',
#    'Philip Holloway'},
#   'Organizations': {'Craigslist'},
#   'Locations': {'South Georgia', 'suburban\xa0Atlanta'},
#   'Dates': {'2023-01-26 00:00:00'}},
#  '0ac8da885d111a70524558202d0971b317c80890.story': {'People': {'Raquel Granell',
#    'Samantha Walker'},
#   'Organizations': {'Asthma UK', 'Bristol University', 'PLOS Medicine'},
#   'Locations': {'UK'},
#   'Dates': {'the end of the 20th century'}},
#  '0acbea1ae921bf7bedb306c60116816c2dc6855d.story': {'People': {'Barry Smith',
#    'Frank McCusker'},
#   'Organizations': {'Allianz\xa0Global Assistance\xa0UK',
#    'Ski Club of Great Britain'},
#   'Locations': {'Austria',
#    'Canada',
#    'North America',
#    'Switzerland',
#    'US',
#    'USA'},
#   'Dates': {'winter'}},
#  '0acf50911732154986d754da646757b7c42508cc.story': {'People': {'Angela Merkel',
#    'Dimitris Mardas',
#    'Greece',
#    'Johan Van Overtveldt',
#    'Nikos Theocharakis'},
#   'Organizations': {'Der Spiegel',
#    'EU',
#    'European Central Bank',
#    'International Monetary Fund(IMF)',
#    'Spiegel Online',
#    'Syriza'},
#   'Locations': set(),
#   'Dates': {'2023-04-09 00:00:00'}},
#  '0ad347031bfb634d46bb733114023ec812c1ae85.story': {'People': {'Barack Obama',
#    'Carl Levin',
#    'Jerry Boykin',
#    'Jessica Lynch',
#    'Leon Panetta',
#    'Marine',
#    'Martin Dempsey',
#    'Nancy Duff Campbell',
#    'Ryan Smith',
#    'Susan Rice',
#    'Terri Kaas'},
#   'Organizations': {'ABC News',
#    "Army's Delta Force",
#    'Congress',
#    'Family Research Council',
#    'MailOnline',
#    'Marine Corps',
#    "National Women's Law Center",
#    'Navy SEALs',
#    'Pentagon',
#    'Senate Armed Services Committee',
#    'Today Show',
#    'United Nations',
#    'Wall Street Journal'},
#   'Locations': {'Afghanistan', 'Baghdad', 'Iraq'},
#   'Dates': {'1994', '2003', '21st century', 'January 2016', 'May 15'}},
#  '0adb3929d8ea2079cea9065af4a16c9a8695780f.story': {'People': {'Bob Hine',
#    'Chris Gigg',
#    'Dolphin Morris Men',
#    'Mia De Graaf',
#    'Morris dancer',
#    'Peter Goode'},
#   'Organizations': {'Department for Transport',
#    'Nottinghamshire County Council'},
#   'Locations': {'Nottingham', 'Southwell'},
#   'Dates': {'1109', '12th century', '1530', '1981', '21st century'}},
#  '0ae424ae15992799870dc89a4fc82925ddeda32a.story': {'People': {'Barry Leonard',
#    'Mallika Kapur',
#    'Miguel Caballero',
#    'Vanessa Emilien'},
#   'Organizations': {'Adlon Kempinski',
#    'Association of Corporate Travel Executives',
#    'British Airways',
#    'Business Traveller',
#    'Oberoi',
#    'US Airways'},
#   'Locations': {'Berlin',
#    "London's Heathrow airport",
#    'Mumbai',
#    "New York's Hudson River",
#    'Sukarno-Hatta airport in\xa0Jakarta'},
#   'Dates': set()},
#  '0ae9a98265905048c44275607043b74c73e195f1.story': {'People': {'Casey Hudson',
#    'Darth Vader',
#    'Gollum',
#    'John Shepard'},
#   'Organizations': {'BioWare', 'Mass Effect', 'Reapers'},
#   'Locations': {'Australia', 'Europe', 'Japan', 'North America'},
#   'Dates': {'March 15', 'March 9'}},
#  '0aed82a5b444877d95bbacb1e5edde54a52d675f.story': {'People': {'Bob Hawkins',
#    'David Niven',
#    'Jennifer Pifer Bixler',
#    'Lucie Bruijn',
#    'Mel Barry',
#    'Sharon Matland',
#    'Stephen Hawking'},
#   'Organizations': {'ALS Association', 'MND Association'},
#   'Locations': {'California',
#    'Cambridge',
#    'England',
#    'Fayetteville',
#    'Ireland',
#    'North Carolina',
#    'Northampton',
#    'Pasadena',
#    'UK',
#    'United States'},
#   'Dates': {'2009'}},
#  '0af24d7e93abbe7a59e6690c420067b8eae221a2.story': {'People': {'Dorothy Urwin',
#    'Nick Hood',
#    'Ros Altmann',
#    'Ruth Sunderland'},
#   'Organizations': {'Care Quality Commission',
#    'Company Watch',
#    'Southern Cross'},
#   'Locations': {'Britain'},
#   'Dates': {'11:01 EST',
#    '19:04 EST',
#    '2011',
#    '25 August 2013',
#    '26 August 2013'}},
#  '0afb432978cfd25ba81848334b7f966c28f97954.story': {'People': {'Andrew Lansley',
#    'David Cameron',
#    'Ed Miliband',
#    'Lindsey Davies'},
#   'Organizations': {'Cabinet',
#    'Health',
#    'House of Lords',
#    'Labour',
#    'Tory',
#    'Wales’s Health Service'},
#   'Locations': {'England'},
#   'Dates': set()},
#  '0b00c7c4c20e7049d731d0123945387add6e51dd.story': {'People': {'Barra Roantree',
#    'Ed Balls',
#    'George Osborne',
#    'Nick Clegg',
#    'Stuart Adam'},
#   'Organizations': {'Institute for Fiscal Studies(IFS)',
#    'Labour',
#    'Standard',
#    'Tory'},
# ...
#    'Geoff Hurst',
#    'Harry',
#    'Harry Kane',
#    'Kane',
#    'Peter',
#    'Peter Osgood',
#    'Ravel Morrison',
#    'Ron Greenwood',
#    'Roy Hodgson',
#    'Ryan Mason',
#    'Teddy Sheringham',
#    'Thomas Muller'},
#   'Organizations': {'Chelsea',
#    'England',
#    'Germany',
#    'Lithuania',
#    'Poland',
#    'Spurs',
#    'Tottenham',
#    'West Germany',
#    'West Ham',
#    'the Bayern Munich'},
#   'Locations': {'Wembley'},
#   'Dates': {'1966', 'February 1966', 'March 27', 'the start of 1966'}},
#  'c219328da37af7c23ade557da0783e484ec0ce4f.story': {'People': {'Broughton',
#    'George Gillett',
#    'John W. Henry',
#    'Martin Broughton',
#    'Mill',
#    'Mill Hicks Gillett',
#    'Mr. Gillett',
#    'Mr. Hicks',
#    'Tom Hicks'},
#   'Organizations': {'BBC',
#    'CNN',
#    'Everton',
#    'Kop Football Holdings',
#    'Liverpool',
#    'Liverpool F.C.',
#    'Liverpool Football Club',
#    'NESV',
#    'New England Sports Ventures',
#    'Premier League clubs',
#    'Press Association',
#    'RBS',
#    'Red Sox',
#    'The Board',
#    'Twitter',
#    'the Royal Bank of Scotland'},
#   'Locations': {'American',
#    'Boston',
#    'Britain',
#    'British',
#    'England',
#    'European',
#    'London',
#    'Texas',
#    'U.S.'},
#   'Dates': {'2005', '2007', 'since 1990'}},
#  'c3cef2355afbb68900efe70b24c1b48f68c3fb0d.story': {'People': {'Alex Ward',
#    'Amber Langford',
#    'Annie Collinge',
#    'Chester MP',
#    'Coleen',
#    'Stephen Mosley',
#    'Wayne Rooney'},
#   'Organizations': {'Chester Chronicle', 'USA Today'},
#   'Locations': {'Austria',
#    'Belgium',
#    'Bergen',
#    'Bruges',
#    'Budapest',
#    'Chester',
#    'Croatia',
#    'Czech Republic',
#    'Dubrovnik',
#    'England',
#    'Europe',
#    'Greece',
#    'Hungary',
#    'Innsbruck',
#    'Italy',
#    'Latvia',
#    'Norway',
#    'Prague',
#    'Riga',
#    'Rome',
#    'Santorini',
#    'Venice'},
#   'Dates': {'05:49 EST  26 November 2013', '09:25 EST', '26 November 2013'}},
#  'c3ea6e43b51f70fa4f4968a7c68cb4391a9d63bb.story': {'People': {'Andy Sephton',
#    'Mr Roche',
#    'Nazia Parveen',
#    'Trevor Roche',
#    'a former Gulf War pilot'},
#   'Organizations': {'British Airways',
#    'RAF',
#    'RAF Tornado',
#    'the Air Accidents Investigation Branch',
#    'the Shuttleworth Collection'},
#   'Locations': {'Biggleswade', 'Old Warden Aerodrome'},
#   'Dates': {'04:20 EST',
#    '06:58 EST',
#    '1 July 2012',
#    '1923',
#    '1927',
#    '1995',
#    '2 July 2012',
#    '2000',
#    '2002'}},
#  'c3ec41a3ca9f0624ebf533ccc0e325172d1489cc.story': {'People': {'Tariq Hayat'},
#   'Organizations': {'Afghanistan',
#    'Azerbaijan',
#    'CNN',
#    'NATO',
#    'Pakistani military',
#    'Pakistani officials',
#    'Taliban militants',
#    'Turkmenistan',
#    'U.S. military supplies',
#    'Uzbekistan',
#    'coalition forces',
#    'supply convoys'},
#   'Locations': {'ISLAMABAD',
#    'Pakistan',
#    'The Khyber Pass',
#    'the Khyber Agency'},
#   'Dates': set()},
#  'c7128352cda329c71eaa85636f0405eb608e4e04.story': {'People': {'Anabel Medina Garrigues',
#    'Andy Roddick',
#    'Eleni Daniilidou',
#    'Gabby Douglas. Venus',
#    'Jeremy Chardy',
#    'Maria Kirilenko',
#    'Samantha Stosur',
#    'Serena Williams',
#    'Urszula Radwanska',
#    'Yaroslava Shevdova'},
#   'Organizations': {'CNN', 'the Bank of West Classic'},
#   'Locations': {'French',
#    'Greek',
#    'Kazakh',
#    'London',
#    'Poland',
#    'Rio',
#    'Russia',
#    'Spain',
#    'the Flushing Meadows'},
#   'Dates': {'2003', '2012', '2016'}},
#  'cc2856da355ca43c4f55f7d5d6760d0a5b263edb.story': {'People': {'Allen West',
#    'Anders Fogh Rasmussen',
#    'Barack Obama',
#    'Blake Farenthold',
#    'James Inhofe',
#    'Jason Chaffetz',
#    'Kerry Bentivolio Tim Scott',
#    'Michael Burgess',
#    'Mocking Obama',
#    'NATO Secretary General',
#    'Obama',
#    'Palin',
#    "Rosie O'Donnell",
#    'Sarah Palin',
#    'Scott',
#    'The onetime Republican vice presidential candidate',
#    'Tim Scott',
#    'Tom Coburn',
#    'Tom Tancredo',
#    'Vladimir Putin',
#    'Whoopi Goldberg'},
#   'Organizations': {'Breitbart.com',
#    'Congress',
#    'IRS',
#    'NSA',
#    'Republican lawmakers',
#    'Republicans',
#    'The Hollywood Reporter',
#    'The South Dakota Republican Party',
#    'White House',
#    'illegal immigrants',
#    'the U.S. Senate',
#    'the White House'},
#   'Locations': {'Central America'},
#   'Dates': {'2011', '2012'}},
#  'cc7388549854539e807948d84fc37a7b9b20d61b.story': {'People': {'Alyssa Smith',
#    'Chris',
#    'Damian Andrade',
#    'Diana Adams',
#    'Engulfed',
#    'Fred',
#    "John D'Agostini",
#    'Scott McLean',
#    'Tim Flaherty',
#    'Wayne Allen Huntsman'},
#   'Organizations': {'Berkeley',
#    'California Logistic',
#    'Forest Service',
#    'French Meadows Reservoir',
#    'The National Weather Service',
#    'University of California',
#    'Wofford Acres Vineyards',
#    'the California Department of Forestry',
#    'the California Department of Forestry and Fire Protection',
#    'the Sequoia National Forest Cobra',
#    'the Tahoe National Forest'},
#   'Locations': {'Apple Hill',
#    'California',
#    'El Dorado County',
#    'Lake Tahoe',
#    'Las Vegas',
#    'Pollock Pines',
#    'Wofford Acres Vineyards',
#    'east of Sacramento'},
#   'Dates': {'September 13', 'between January 1 and September 20'}},
#  'ccca8cc860b0f58a2ed643d016c022e66536ec42.story': {'People': {'Claire Nugent',
#    'Hitler',
#    'Jill Reilly',
#    'Nigel Morter'},
#   'Organizations': {'No 171 Squadron',
#    'No 274 Maintenance Unit',
#    'RAF',
#    'squadrons of the RAF’s new No 100 Group'},
#   'Locations': {'Holkham Estate',
#    'North Creake airfield',
#    'the Pas-de-Calais area'},
#   'Dates': {'08:10 EST',
#    '14:39 EST',
#    '1930s',
#    '1950s',
#    '7 November 2012',
#    '8 November 2012',
#    'May 1944',
#    'November 23 1943',
#    'October 2011',
#    'September 1944',
#    'the spring of 1944'}},
#  'd305159fb796ddc13ad5dbb31c04d8a7d5c6268f.story': {'People': {'AP Photo/Courtesy',
#    'Amber',
#    'Bruce Johnson',
#    'Chan',
#    'Dr Kent Brantly',
#    'Dr Thomas Frieden',
#    'Jeremy Writebol',
#    'Joanne Liu',
#    'Margaret Chan',
#    'Mrs Writebol',
#    'Nancy Writebol',
#    'Vincent Martin'},
#   'Organizations': {'A U.S. missionary charity',
#    'CDC',
#    'Doctor Without Borders (Medecins Sans Frontieres - MSF)',
#    'ELWA',
#    'Elwa hospita',
#    'Emory University Hospital',
#    'FAO',
#    'SIM',
#    'SIM USA',
#    'Serving In Mission',
#    'U.N.',
#    'WHO',
#    'World Health Organization',
#    'the Centers for Disease Control and Prevention',
#    'the U.N. FAO',
#    'the U.N. Food and Agriculture Organization'},
#   'Locations': {'Atlanta',
#    'Guinea',
#    'Liberia',
#    'Monrovia',
#    'Nigeria',
#    'Sierra Leone',
#    'West Africa'},
#   'Dates': {'2023-08-21 00:00:00'}},
#  'd415537ea8a0a765e786ef0bb423090e5b8ab391.story': {'People': {'George Osborne',
#    'Hugo Duncan',
#    'Jeremy Blackburn',
#    'Northern Rock',
#    'Stephen Herring',
#    'Stuart Adam'},
#   'Organizations': {'Experts',
#    'Government',
#    'The Institute of Directors',
#    'The Office for National Statistics',
#    'the Institute for Fiscal Studies',
#    'the Royal Institution of Chartered Surveyors',
#    'the critics'},
#   'Locations': {'UK'},
#   'Dates': {'2003', '2008', '2013', 'August 2007', 'July 2013', 'March 2009'}},
#  'dbf45ddb53f321bfbc9f72f5443f232e0f64e3a9.story': {'People': {'Alex Davey',
#    'Carragher',
#    'Fankaty Dabo',
#    'Fikayo Tomori',
#    'Harry Wilson',
#    'Jamie Carragher',
#    'Jerome Sinclair',
#    'Joe Riley',
#    'Krisztian Adorjan',
#    'Mike Marsh',
#    'Raheem Sterling',
#    'Ro-Shaun Williams',
#    'Robbie',
#    'Robbie Fowler',
#    'Rodolfo Borrell',
#    'Sinclair',
#    'Steven Gerrard',
#    'Stuart Webber',
#    'Tomori'},
#   'Organizations': {'Blues',
#    'Chelsea',
#    'England',
#    'Inter Milan',
#    'Italy',
#    'Liverpool',
#    'Manchester United',
#    'Morocco',
#    'Real Madrid',
#    'Rosenborg',
#    'Sky Sports',
#    'Sportsmail',
#    'Wales',
#    'West Brom',
#    'the Liverpool Echo'},
#   'Locations': {'Anfield',
#    'Birmingham',
#    'Burton',
#    'Deva Stadium',
#    'England',
#    'France',
#    'Melwood',
#    'The Hawthorn',
#    'Victory Shield'},
#   'Dates': {'2011-2012',
#    '2012',
#    'April 2013',
#    'October 2011',
#    'September 1996',
#    'september 2012'}},
#  'ddc527f81c55302c6972a61df336a4ce37619e16.story': {'People': {'Eric Holthaus',
#    'Hunter Mahan',
#    'Luke Donald',
#    'McIlroy',
#    'Rickie Fowler',
#    'Rory McIlroy',
#    'Steve Nolan',
#    'Tiger Woods'},
#   'Organizations': {'Twitter',
#    'the New York Times',
#    'the Ritz Carlton Club',
#    'the US National Weather Service'},
#   'Locations': {'Alaska',
#    'Arizona',
#    'Dove Mountain',
#    'Golfer Chris Wood',
#    'Qatar',
#    'Tortolita Mountain park',
#    'Tucson',
#    'UK'},
#   'Dates': {'07:46 EST',
#    '1894',
#    '20 February 2013',
#    '21 February 2013',
#    '21:04 EST',
#    'February 27 2011',
#    'January 30 2002'}},
#  'df8071d652d84b27d411ac00c85a028d7e72fc7c.story': {'People': {'David de Gea',
#    'Fernando Macias',
#    'Gareth Bale',
#    'Lucas Silva',
#    'Luis Suarez',
#    'Manuel Godoy',
#    'Martin Odegaard',
#    'Silva'},
#   'Organizations': {'AS',
#    'Barcelona',
#    'CAS',
#    'FIFA',
#    'FIFA誷 Players Status Committee',
#    'ITC',
#    'International Transfer Certificate',
#    'Liverpool',
#    'Madrid',
#    'Manchester United',
#    'Milan',
#    'RFEF',
#    'Rayo Vallecano',
#    'Real',
#    'Real Madrid',
#    'River Plate',
#    'the Court of Arbitration for Sport'},
#   'Locations': {'Barajas', 'Cordoba', 'Spain', 'Valdebebas', 'Venezuela'},
#   'Dates': {'2009', '2012', '2013', '2015', 'between 2009 and 2013'}},
#  'e6b851358e3c2e5391b42141518630bba1bf1eb7.story': {'People': {'Howard',
#    'Steve Johnson',
#    'Tim',
#    'Tim Howard'},
#   'Organizations': {'Everton',
#    'Everton in the Community',
#    'Medicash',
#    'Toffees'},
#   'Locations': {'Croxteth Sports Centre'},
#   'Dates': set()},
#  'e8e0c65bd956546ea81e8d2bd81f6aaec94831d5.story': {'People': {'Borini',
#    'Connor',
#    'Connor Wickham',
#    'Fabio Borini',
#    'Gus Poyet'},
#   'Organizations': {'Black Cats', 'Liverpool', 'Sunderland', 'West Brom'},
#   'Locations': {'Stadium of Light', 'Wearside'},
#   'Dates': set()},
#  'ec92eeb018ae9348d93ef9b2dd80cc81fed3c2eb.story': {'People': {'Alan Irvine',
#    'Irvine',
#    'Joleon',
#    'Joleon Lescott',
#    'Lescott'},
#   'Organizations': {'Baggies',
#    'City',
#    'Manchester City',
#    'QPR',
#    'Stoke',
#    'West Brom',
#    'West Bromwich Albion',
#    'West Ham'},
#   'Locations': {'Loftus Road'},
#   'Dates': {'Christmas'}},
#  'f4044e398c7a68b1af43995677bdf80ac0657014.story': {'People': {'Andres Iniesta',
#    'Angel Di Maria',
#    'Arjen Robben',
#    'Cristiano Ronaldo',
#    'Diego Costa',
#    'Franck Ribery',
#    'Gareth Bale',
#    'James Rodriguez',
#    'Lionel Messi',
#    'Luis Suarez',
#    'Manuel Neuer',
#    'Neuer',
#    'Philipp Lahm',
#    'Robben',
#    'Ronaldo',
#    'Thomas Muller'},
#   'Organizations': {'AS Monaco',
#    'Argentina',
#    'Atletico Madrid',
#    'Barcelona',
#    'Bayern',
#    'Bayern Munich',
#    'Chelsea',
#    'Colombia',
#    'Europe Award',
#    'German',
#    'Germany',
#    'Holland',
#    'Liverpool',
#    'Real',
#    'Real Madrid',
#    'Sevilla',
#    'Spain',
#    'UEFA',
#    'Uruguay'},
#   'Locations': {'Brazil', 'Europe', 'Monaco'},
#   'Dates': {'2010-11',
#    '2011',
#    '2011-12',
#    '2012-13',
#    '2013-14',
#    '2014-15',
#    'August 28'}},
#  'fe3dd15fe1b59a96fe4162553279dd1ed263d121.story': {'People': {'Fishman',
#    'Lauri Love',
#    'Paul Fishman'},
#   'Organizations': {'A federal grand jury',
#    'Army',
#    'CNN',
#    'NASA',
#    'the Environmental Protection Agency'},
#   'Locations': {'England', 'Stradishall'},
#   'Dates': set()},
#  'feb0bd824bfa76f71edccd48c1f167b42a210c8b.story': {'People': {'Andros Townsend',
#    'Christian Eriksen',
#    'Erik Lamela',
#    'Jeffery Schlupp',
#    'Lamela',
#    'Leandro Ulloa',
#    'Ryan Shawcross',
#    'Townsend'},
#   'Organizations': {'Blades',
#    'Leicester',
#    'Roma',
#    'Sheffield United',
#    'Spurs',
#    'Stoke City',
#    'Tottenham',
#    'the Evening Standard'},
#   'Locations': {'White Hart Lane'},
#   'Dates': {'2008', '2013'}},
#  'ff0f9801334d6f97b2b05c390a7313cfc3e64140.story': {'People': {'Heath Montgomery',
#    'Kari Bowen'},
#   'Organizations': {'Associated Press',
#    'Frontier Airlines',
#    'The National Weather Service',
#    'the San Francisco Giants'},
#   'Locations': {'Colorado',
#    'Lafayette',
#    'Midwest',
#    'Northeast',
#    'Red Feather',
#    'West',
#    'the West Coast'},
#   'Dates': set()},
#  'ff18a63fb30d6b696e725f2d4009ddd13a4146a2.story': {'People': set(),
#   'Organizations': {'Aquatica',
#    'Aquaventure Water Park at Atlantis',
#    'Aquaventure Waterpark',
#    'Beach Park',
#    'Beto Carrero World',
#    'Brazil',
#    'Discovery Cove',
#    'Disney',
#    "Disney's Animal Kingdom",
#    "Disney's Blizzard Beach Water Park",
#    "Disney's Hollywood Studios",
#    "Disney's Typhoon Lagoon Water Park",
#    'Europa Park',
#    'Hot Park',
#    'PortAventura Park',
#    'Rio Quente',
#    'Siam Park',
#    'TripAdvisor',
#    'Universal Studios Singapore',
#    "Universal's Islands of Adventure",
#    'Waterbom Bali',
#    'Wild Wadi Water Park'},
#   'Locations': {'Adeje',
#    'Anaheim',
#    'Aquiraz',
#    'Brazil',
#    'Brazil7. Disneyland Park',
#    'California',
#    'Dubai',
#    'Florida',
#    'Germany',
#    'Indonesia',
#    'Kuta',
#    'Magic Kingdom',
#    'Orlando',
#    'Paradise Island',
#    'Penha',
#    'Rio Quente',
#    'Rust',
#    'Salou',
#    'Sentosa Island',
#    'Singapore',
#    'Spain',
#    'United Arab Emirates'},
#   'Dates': set()},
#  'ff6bb1e8a47fdd6c32f14201b7aa50dd7720a9ca.story': {'People': {'Alan Clarke',
#    'David Cameron',
#    'Diamond Jubilee',
#    'Jubilee',
#    'Kate Middleton',
#    'Prince William',
#    'Rick Dewsbury',
#    'Sir Mervyn',
#    'Sir Mervyn King',
#    'Spencer Dale'},
#   'Organizations': {'Bank of England',
#    'Britain',
#    'Eurozone',
#    'Goldman Sachs',
#    'Royal',
#    'Scotiabank',
#    'the House of Lords Economic Affairs Committee'},
#   'Locations': {'London', 'UK'},
#   'Dates': {'04:23 EST',
#    '06:48 EST',
#    '17 May 2012',
#    '2009',
#    '2012',
#    'June 4 and 5',
#    'the fourth quarter of 2011'}},
#  'ff95cbf06bc9e4b2b0c4bb7b46794e63cacaa834.story': {'People': {'Carolyn Wu',
#    'Tim Cook'},
#   'Organizations': {'Apple',
#    'Apple Inc.',
#    'LCD',
#    'Proview',
#    'Proview International',
#    'Proview International Holdings Ltd.',
#    'Proview Taipei',
#    'Shenzhen Proview Technology',
#    'The Apple Store',
#    'Xinhua',
#    'the Municipal Intermediate People’s Court'},
#   'Locations': {'China', 'Southern China'},
#   'Dates': {'2001', '2009', 'as early as 2000'}},
#  'ffcbb4742e7df96316bda9385d8ec14078aa5b3f.story': {'People': {'Briseno',
#    'Cynthia Kelly',
#    'George Holliday',
#    'John Davies',
#    'Koon',
#    'Laurence Michael Powell',
#    'Pete Wilson',
#    'Powell',
#    'Reginald Denny',
#    "Rodney King's",
#    'Stacey Koon',
#    'Stanley Weisberg',
#    'Theodore Briseno',
#    'Timothy Wind',
#    'Wind'},
#   'Organizations': {'Florence and Normandie',
#    'KTLA',
#    'Superior Court',
#    'The U.S. District Court',
#    'U.S. District',
#    'the LA Riots'},
#   'Locations': set(),
#   'Dates': {'1991',
#    '1992',
#    '1993',
#    '1994',
#    '2012',
#    'April 16',
#    'April 19',
#    'April 2012',
#    'April 29',
#    'April 30-May 4',
#    'August 4',
#    'February 25',
#    'June 1',
#    'June 17',
#    'March 15',
#    'March 3',
#    'March 4',
#    'March 7',
#    'May 1',
#    'May 10',
#    'November 26'}},
#  'ffd480659edff188a04fbd2114b0f63113669407.story': {'People': {'Putin',
#    'Vladimir Putin'},
#   'Organizations': set(),
#   'Locations': {'Moscow', 'Russia', 'Ukraine'},
#   'Dates': set()},
#  'fffb9fbf64cc936c10ecef14b684ac67b6b6b9e7.story': {'People': {'Railway Gazette',
#    'Rick Scott',
#    'Roy LaHood',
#    'Shinkansen'},
#   'Organizations': {'AVE',
#    'Acela Express',
#    'Amtrak',
#    'CEI',
#    'EU',
#    'FRA',
#    'Korea Train Express',
#    'Transportation Secretary',
#    'the Competitive Enterprise Institute',
#    'the European Union',
#    'the Federal Railroad Administration',
#    'the International Union of Railways',
#    'the White House'},
#   'Locations': {'California',
#    'Europe',
#    'Florida',
#    'New York and New England',
#    'Pennsylvania',
#    'Santiago de Compostela',
#    'Spain',
#    'United States',
#    'the Gulf Coast',
#    'the Midwest',
#    'the Pacific Northwest',
#    'the Southeast'},
#   'Dates': {'2010'}}}

# %%
# 导出为 Excel 文件
df2 = pd.DataFrame(ground_truth)
df2_transposed = df2.transpose()

excel_path = '/Users/irisgong/Desktop/ISE540 Text Analytics/project/ground_truth.xlsx'
df2_transposed.to_excel(excel_path, index=False)

# 打印成功消息
print(f'DataFrame已成功导出到 {excel_path}')
# Out:
# DataFrame已成功导出到 /Users/irisgong/Desktop/ISE540 Text Analytics/project/ground_truth.xlsx

# %%
def calculate_precision_recall_for_file(ground_truth, retrieved_documents, file_id, label):
    ground_truth_labels = set(ground_truth[file_id].get(label, []))
    retrieved_labels = set(retrieved_documents.get(file_id, {}).get(label, []))

    true_positives = len(ground_truth_labels & retrieved_labels)
    false_positives = len(retrieved_labels - ground_truth_labels)
    false_negatives = len(ground_truth_labels - retrieved_labels)

    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) != 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) != 0 else 0

    return precision, recall


result_df = pd.DataFrame(columns=[
    'File_ID',
    'Precision_Person', 'Recall_Person',
    'Precision_Org', 'Recall_Org',
    'Precision_Loc', 'Recall_Loc',
    'Precision_Date', 'Recall_Date'
])

# 遍历每个文档
for file_id in ground_truth.keys():
    # 计算每个标签的精确度和召回率
    precision_person, recall_person = calculate_precision_recall_for_file(ground_truth, retrieved_documents, file_id, 'People')
    precision_org, recall_org = calculate_precision_recall_for_file(ground_truth, retrieved_documents, file_id, 'Organizations')
    precision_loc, recall_loc = calculate_precision_recall_for_file(ground_truth, retrieved_documents, file_id, 'Locations')
    precision_date, recall_date = calculate_precision_recall_for_file(ground_truth, retrieved_documents, file_id, 'Dates')

    # Append the results to the DataFrame
    result_df = pd.concat([result_df, pd.DataFrame({
        'File_ID': [file_id],
        'Precision_Person': [precision_person],
        'Recall_Person': [recall_person],
        'Precision_Org': [precision_org],
        'Recall_Org': [recall_org],
        'Precision_Loc': [precision_loc],
        'Recall_Loc': [recall_loc],
        'Precision_Date': [precision_date],
        'Recall_Date': [recall_date]
    })], ignore_index=True)

    

result_df
# Out:
#                                             File_ID  Precision_Person  \
# 0    0000800d9058217f6509d7e63ad475e2de0da611.story          0.727273
# 1    0001d4ce3598e37f20a47fe609736f72e5d73467.story          0.428571
# 2    0002067d13d3ca304e0bc98d04dde85d4091c55e.story          0.500000
# 3    000219931d2c3aae55dc2acdc5f690d0c112ab17.story          0.538462
# 4    00022dbfa44ccdb94c1dc06938047e258076cf75.story          0.571429
# ..                                              ...               ...
# 245  ff6bb1e8a47fdd6c32f14201b7aa50dd7720a9ca.story          0.700000
# 246  ff95cbf06bc9e4b2b0c4bb7b46794e63cacaa834.story          0.500000
# 247  ffcbb4742e7df96316bda9385d8ec14078aa5b3f.story          0.777778
# 248  ffd480659edff188a04fbd2114b0f63113669407.story          1.000000
# 249  fffb9fbf64cc936c10ecef14b684ac67b6b6b9e7.story          0.666667
#
#      Recall_Person  Precision_Org  Recall_Org  Precision_Loc  Recall_Loc  \
# 0         0.615385       0.000000    0.000000       0.777778    0.875000
# 1         0.600000       0.090909    0.200000       0.555556    0.833333
# 2         0.571429       0.400000    1.000000       0.400000    0.666667
# 3         0.777778       0.333333    0.333333       0.600000    1.000000
# 4         1.000000       0.400000    1.000000       0.200000    1.000000
# ..             ...            ...         ...            ...         ...
# 245       0.700000       0.555556    0.714286       0.400000    1.000000
# 246       1.000000       0.833333    0.909091       0.222222    1.000000
# 247       0.933333       0.500000    0.500000       0.000000    0.000000
# 248       1.000000       0.000000    0.000000       0.600000    1.000000
# 249       0.500000       0.705882    0.923077       0.219512    0.750000
#
#      Precision_Date Recall_Date
# 0          0.000000           0
# 1          0.000000           0
# 2          0.666667         0.8
# 3          0.250000         0.5
# 4          0.000000         0.0
# ..              ...         ...
# 245        0.230769    0.428571
# 246        1.000000         1.0
# 247        0.157895    0.142857
# 248        0.000000           0
# 249        0.500000         1.0
#
# [250 rows x 9 columns]

# %%
# 导出为 Excel 文件
excel_path = '/Users/irisgong/Desktop/ISE540 Text Analytics/project/precision&recall.xlsx'
result_df.to_excel(excel_path, index=False)

# 打印成功消息
print(f'DataFrame已成功导出到 {excel_path}')
# Out:
# DataFrame已成功导出到 /Users/irisgong/Desktop/ISE540 Text Analytics/project/precision&recall.xlsx
